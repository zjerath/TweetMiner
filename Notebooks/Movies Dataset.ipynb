# %% [markdown]
# ## Imports

# %%
import pandas as pd
import ast

# %% [markdown]
# ## Datasets

# %%
credits = pd.read_csv('credits.csv')
movies = pd.read_csv('movies_metadata.csv')
# Out:
# /var/folders/dt/ywvbqwcj3hn_5x4g7z8p1tq00000gn/T/ipykernel_9859/1991119359.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv('movies_metadata.csv')

# %%
movies.head(1)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
#
#   release_date      revenue runtime                          spoken_languages  \
# 0   1995-10-30  373554033.0    81.0  [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status  tagline      title  video vote_average vote_count
# 0  Released      NaN  Toy Story  False          7.7     5415.0
#
# [1 rows x 24 columns]

# %% [markdown]
# ## Cleaning

# %%
# remove unnecessary columns
movies.drop(columns=['belongs_to_collection', 'budget', 'homepage', 'imdb_id', 'overview', 'poster_path', 'runtime', 'status', 'tagline', 'video'], inplace=True)

# %%
movies.head(1)
# Out:
#    adult                                             genres   id  \
# 0  False  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  862
#
#   original_language original_title popularity  \
# 0                en      Toy Story  21.946943
#
#                              production_companies  \
# 0  [{'name': 'Pixar Animation Studios', 'id': 3}]
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
#
#        revenue                          spoken_languages      title  \
# 0  373554033.0  [{'iso_639_1': 'en', 'name': 'English'}]  Toy Story
#
#    vote_average  vote_count
# 0           7.7      5415.0

# %%
# function to check int id types
def is_integer(val):
    try:
        # try to convert to int
        int(val)
        return True
    except (ValueError, TypeError):
        return False

# filter rows where 'id' is an integer-like value
movies = movies[movies.id.apply(is_integer)]

# convert 'id' column to int
movies.id = movies.id.astype(int)

# merge with credits df
df = pd.merge(movies, credits, on='id')
df.drop(columns=['id'], inplace=True)

# %%
df.head(1)
# Out:
#    adult                                             genres original_language  \
# 0  False  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...                en
#
#   original_title popularity                            production_companies  \
# 0      Toy Story  21.946943  [{'name': 'Pixar Animation Studios', 'id': 3}]
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
#
#        revenue                          spoken_languages      title  \
# 0  373554033.0  [{'iso_639_1': 'en', 'name': 'English'}]  Toy Story
#
#    vote_average  vote_count  \
# 0           7.7      5415.0
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
#
#                                                 crew
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...

# %%
# extract the category names
def extract_names(name_str):
    if pd.isna(name_str):
        return []
    # convert the string representation of the list to an actual list
    str_list = ast.literal_eval(name_str)
    # extract the 'name' from each dictionary in the list
    names = [i['name'] for i in str_list]
    # return list of names as a string
    return ', '.join(names)

# clean the cast data
def clean_cast_data(cast_str):
    # convert string representation of the list to an actual list
    cast_list = ast.literal_eval(cast_str)

    # extract relevant fields and change gender values
    cleaned_cast = []
    for member in cast_list:
        cleaned_member = {
            'character': member['character'],
            'gender': 'm' if member['gender'] == 2 else 'f' if member['gender'] == 1 else None,
            'name': member['name'],
            'order': member['order']
        }
        cleaned_cast.append(cleaned_member)
    return cleaned_cast

# clean the crew data
def clean_crew_data(crew_str):
    # convert string representation of the list to an actual list
    crew_list = ast.literal_eval(crew_str)

    # extract relevant fields
    cleaned_crew = []
    for member in crew_list:
        cleaned_member = {
            'job': member['job'],
            'name': member['name']
        }
        cleaned_crew.append(cleaned_member)
    return cleaned_crew

# clean columns
cols = ['genres', 'production_companies', 'production_countries', 'spoken_languages']
for col in cols:
    df[col] = df[col].apply(extract_names)
df.release_date = pd.to_datetime(df.release_date)
df.cast = df.cast.apply(clean_cast_data)
df.crew = df.crew.apply(clean_crew_data)

# %%
df.head(1)
# Out:
#    adult                     genres original_language original_title  \
# 0  False  Animation, Comedy, Family                en      Toy Story
#
#   popularity     production_companies      production_countries release_date  \
# 0  21.946943  Pixar Animation Studios  United States of America   1995-10-30
#
#        revenue spoken_languages      title  vote_average  vote_count  \
# 0  373554033.0          English  Toy Story           7.7      5415.0
#
#                                                 cast  \
# 0  [{'character': 'Woody (voice)', 'gender': 'm',...
#
#                                                 crew
# 0  [{'job': 'Director', 'name': 'John Lasseter'},...

# %% [markdown]
# ## Example Usages

# %%
df[df.original_title == 'Toy Story']
# Out:
#    adult                     genres original_language original_title  \
# 0  False  Animation, Comedy, Family                en      Toy Story
#
#   popularity     production_companies      production_countries release_date  \
# 0  21.946943  Pixar Animation Studios  United States of America   1995-10-30
#
#        revenue spoken_languages      title  vote_average  vote_count  \
# 0  373554033.0          English  Toy Story           7.7      5415.0
#
#                                                 cast  \
# 0  [{'character': 'Woody (voice)', 'gender': 'm',...
#
#                                                 crew
# 0  [{'job': 'Director', 'name': 'John Lasseter'},...

# %%
'Comedy' in df[df.original_title == 'Toy Story'].genres[0]
# Out:
# True

# %%
df[df['release_date'].dt.year == 2013]
# Out:
#        adult           genres original_language  \
# 1090   False   Comedy, Horror                en
# 4370   False            Drama                fr
# 4371   False            Drama                fr
# 4372   False            Drama                fr
# 4373   False            Drama                fr
# ...      ...              ...               ...
# 45397  False           Comedy                fr
# 45414  False            Drama                en
# 45431  False                                 en
# 45448  False  Comedy, Romance                ru
# 45451  False                                 uk
#
#                                    original_title popularity  \
# 1090                                The Sleepover   0.135596
# 4370                         Camille Claudel 1915   0.134014
# 4371                         Camille Claudel 1915   0.134014
# 4372                         Camille Claudel 1915   0.110065
# 4373                         Camille Claudel 1915   0.110065
# ...                                           ...        ...
# 45397                      La Fille du 14 juillet   1.096974
# 45414                                  Over/Under   0.704642
# 45431  What a Fuck Am I Doing on This Battlefield   0.020752
# 45448                               Полярный рейс   0.036523
# 45451                                   Іван Сила   0.067263
#
#                                     production_companies  \
# 1090
# 4370   Canal+, Arte France Cinéma, 3B Productions, C....
# 4371   Canal+, Arte France Cinéma, 3B Productions, C....
# 4372   Canal+, Arte France Cinéma, 3B Productions, C....
# 4373   Canal+, Arte France Cinéma, 3B Productions, C....
# ...                                                  ...
# 45397                                         Ecce Films
# 45414  Fox Television Studios, Universal Cable Produc...
# 45431
# 45448                                        Wise Vision
# 45451
#
#            production_countries release_date   revenue spoken_languages  \
# 1090                              2013-10-12       0.0
# 4370                     France   2013-03-13  115860.0         Français
# 4371                     France   2013-03-13  115860.0         Français
# 4372                     France   2013-03-13  115860.0         Français
# 4373                     France   2013-03-13  115860.0         Français
# ...                         ...          ...       ...              ...
# 45397                    France   2013-06-05       0.0         Français
# 45414  United States of America   2013-01-04       0.0          English
# 45431                             2013-04-22       0.0
# 45448                   Ukraine   2013-12-12       0.0          Pусский
# 45451                             2013-10-02       0.0      Український
#
#                                             title  vote_average  vote_count  \
# 1090                                The Sleepover           8.0         1.0
# 4370                         Camille Claudel 1915           7.0        20.0
# 4371                         Camille Claudel 1915           7.0        20.0
# 4372                         Camille Claudel 1915           7.0        20.0
# 4373                         Camille Claudel 1915           7.0        20.0
# ...                                           ...           ...         ...
# 45397                  The Rendez-Vous of Déjà-Vu           6.2        13.0
# 45414                                  Over/Under           4.0         2.0
# 45431  What a Fuck Am I Doing on This Battlefield           0.0         0.0
# 45448                                Polar Flight           0.0         0.0
# 45451                                   Іван Сила           7.0         1.0
#
#                                                     cast  \
# 1090   [{'character': 'Rachel', 'gender': None, 'name...
# 4370   [{'character': 'Camille Claudel', 'gender': 'f...
# 4371   [{'character': 'Camille Claudel', 'gender': 'f...
# 4372   [{'character': 'Camille Claudel', 'gender': 'f...
# 4373   [{'character': 'Camille Claudel', 'gender': 'f...
# ...                                                  ...
# 45397  [{'character': 'Truquette', 'gender': 'f', 'na...
# 45414  [{'character': '', 'gender': 'm', 'name': 'Ste...
# 45431                                                 []
# 45448  [{'character': '', 'gender': None, 'name': 'Eg...
# 45451  [{'character': 'Ivan Syla', 'gender': None, 'n...
#
#                                                     crew
# 1090      [{'job': 'Director', 'name': 'Chris Cullari'}]
# 4370   [{'job': 'Director', 'name': 'Bruno Dumont'}, ...
# 4371   [{'job': 'Producer', 'name': 'Rachid Bouchareb...
# 4372   [{'job': 'Director', 'name': 'Bruno Dumont'}, ...
# 4373   [{'job': 'Producer', 'name': 'Rachid Bouchareb...
# ...                                                  ...
# 45397  [{'job': 'Director', 'name': 'Antonin Peretjat...
# 45414  [{'job': 'Director', 'name': 'Bronwen Hughes'}...
# 45431  [{'job': 'Director', 'name': 'Julien Fezans'},...
# 45448  [{'job': 'Writer', 'name': 'Aleksandr Kachan'}...
# 45451  [{'job': 'Director', 'name': 'Viktor Andrienko'}]
#
# [1895 rows x 15 columns]

# %%
df[df.original_title == 'Toy Story'].cast.values[0]
# Out:
# [{'character': 'Woody (voice)',
#   'gender': 'm',
#   'name': 'Tom Hanks',
#   'order': 0},
#  {'character': 'Buzz Lightyear (voice)',
#   'gender': 'm',
#   'name': 'Tim Allen',
#   'order': 1},
#  {'character': 'Mr. Potato Head (voice)',
#   'gender': 'm',
#   'name': 'Don Rickles',
#   'order': 2},
#  {'character': 'Slinky Dog (voice)',
#   'gender': 'm',
#   'name': 'Jim Varney',
#   'order': 3},
#  {'character': 'Rex (voice)',
#   'gender': 'm',
#   'name': 'Wallace Shawn',
#   'order': 4},
#  {'character': 'Hamm (voice)',
#   'gender': 'm',
#   'name': 'John Ratzenberger',
#   'order': 5},
#  {'character': 'Bo Peep (voice)',
#   'gender': 'f',
#   'name': 'Annie Potts',
#   'order': 6},
#  {'character': 'Andy (voice)',
#   'gender': None,
#   'name': 'John Morris',
#   'order': 7},
#  {'character': 'Sid (voice)',
#   'gender': 'm',
#   'name': 'Erik von Detten',
#   'order': 8},
#  {'character': 'Mrs. Davis (voice)',
#   'gender': 'f',
#   'name': 'Laurie Metcalf',
#   'order': 9},
#  {'character': 'Sergeant (voice)',
#   'gender': 'm',
#   'name': 'R. Lee Ermey',
#   'order': 10},
#  {'character': 'Hannah (voice)',
#   'gender': 'f',
#   'name': 'Sarah Freeman',
#   'order': 11},
#  {'character': 'TV Announcer (voice)',
#   'gender': 'm',
#   'name': 'Penn Jillette',
#   'order': 12}]

# %%
df[df.original_title == 'Toy Story'].crew.values[0]
# Out:
# [{'job': 'Director', 'name': 'John Lasseter'},
#  {'job': 'Screenplay', 'name': 'Joss Whedon'},
#  {'job': 'Screenplay', 'name': 'Andrew Stanton'},
#  {'job': 'Screenplay', 'name': 'Joel Cohen'},
#  {'job': 'Screenplay', 'name': 'Alec Sokolow'},
#  {'job': 'Producer', 'name': 'Bonnie Arnold'},
#  {'job': 'Executive Producer', 'name': 'Ed Catmull'},
#  {'job': 'Producer', 'name': 'Ralph Guggenheim'},
#  {'job': 'Executive Producer', 'name': 'Steve Jobs'},
#  {'job': 'Editor', 'name': 'Lee Unkrich'},
#  {'job': 'Art Direction', 'name': 'Ralph Eggleston'},
#  {'job': 'Editor', 'name': 'Robert Gordon'},
#  {'job': 'Foley Editor', 'name': 'Mary Helen Leasman'},
#  {'job': 'Animation', 'name': 'Kim Blanchette'},
#  {'job': 'ADR Editor', 'name': 'Marilyn McCoppen'},
#  {'job': 'Orchestrator', 'name': 'Randy Newman'},
#  {'job': 'Color Timer', 'name': 'Dale E. Grahn'},
#  {'job': 'CG Painter', 'name': 'Robin Cooper'},
#  {'job': 'Original Story', 'name': 'John Lasseter'},
#  {'job': 'Original Story', 'name': 'Pete Docter'},
#  {'job': 'Original Story', 'name': 'Joe Ranft'},
#  {'job': 'Post Production Supervisor', 'name': 'Patsy Bouge'},
#  {'job': 'Sculptor', 'name': 'Norm DeCarlo'},
#  {'job': 'Animation Director', 'name': 'Ash Brannon'},
#  {'job': 'Music', 'name': 'Randy Newman'},
#  {'job': 'Layout', 'name': 'Roman Figun'},
#  {'job': 'Orchestrator', 'name': 'Don Davis'},
#  {'job': 'Music Editor', 'name': 'James Flamberg'},
#  {'job': 'Negative Cutter', 'name': 'Mary Beth Smith'},
#  {'job': 'Negative Cutter', 'name': 'Rick Mackay'},
#  {'job': 'Title Designer', 'name': 'Susan Bradley'},
#  {'job': 'Supervising Technical Director', 'name': 'William Reeves'},
#  {'job': 'Songs', 'name': 'Randy Newman'},
#  {'job': 'Original Story', 'name': 'Andrew Stanton'},
#  {'job': 'Supervising Animator', 'name': 'Pete Docter'},
#  {'job': 'Sound Designer', 'name': 'Gary Rydstrom'},
#  {'job': 'Production Supervisor', 'name': 'Karen Robert Jackson'},
#  {'job': 'Executive Music Producer', 'name': 'Chris Montan'},
#  {'job': 'Animation Director', 'name': 'Rich Quade'},
#  {'job': 'Animation', 'name': 'Michael Berenstein'},
#  {'job': 'Animation', 'name': 'Colin Brady'},
#  {'job': 'Animation', 'name': 'Davey Crockett Feiten'},
#  {'job': 'Animation', 'name': 'Angie Glocka'},
#  {'job': 'Animation', 'name': 'Rex Grignon'},
#  {'job': 'Animation', 'name': 'Tom K. Gurney'},
#  {'job': 'Animation', 'name': 'Jimmy Hayward'},
#  {'job': 'Animation', 'name': 'Hal T. Hickel'},
#  {'job': 'Animation', 'name': 'Karen Kiser'},
#  {'job': 'Animation', 'name': 'Anthony B. LaMolinara'},
#  {'job': 'Animation', 'name': 'Guionne Leroy'},
#  {'job': 'Animation', 'name': 'Bud Luckey'},
#  {'job': 'Animation', 'name': 'Les Major'},
#  {'job': 'Animation', 'name': 'Glenn McQueen'},
#  {'job': 'Animation', 'name': 'Mark Oftedal'},
#  {'job': 'Animation', 'name': 'Jeff Pidgeon'},
#  {'job': 'Animation', 'name': 'Jeff Pratt'},
#  {'job': 'Animation', 'name': 'Steve Rabatich'},
#  {'job': 'Animation', 'name': 'Roger Rose'},
#  {'job': 'Animation', 'name': 'Steve Segal'},
#  {'job': 'Animation', 'name': 'Doug Sheppeck'},
#  {'job': 'Animation', 'name': 'Alan Sperling'},
#  {'job': 'Animation', 'name': 'Doug Sweetland'},
#  {'job': 'Animation', 'name': 'David Tart'},
#  {'job': 'Animation', 'name': 'Ken Willard'},
#  {'job': 'Visual Effects Supervisor', 'name': 'Thomas Porter'},
#  {'job': 'Visual Effects', 'name': 'Mark Thomas Henne'},
#  {'job': 'Visual Effects', 'name': 'Oren Jacob'},
#  {'job': 'Visual Effects', 'name': 'Darwyn Peachey'},
#  {'job': 'Visual Effects', 'name': 'Mitch Prater'},
#  {'job': 'Visual Effects', 'name': 'Brian M. Rosen'},
#  {'job': 'Lighting Supervisor', 'name': 'Sharon Calahan'},
#  {'job': 'Lighting Supervisor', 'name': 'Galyn Susman'},
#  {'job': 'CG Painter', 'name': 'William Cone'},
#  {'job': 'Sculptor', 'name': 'Shelley Daniels Lekven'},
#  {'job': 'Character Designer', 'name': 'Bob Pauley'},
#  {'job': 'Character Designer', 'name': 'Bud Luckey'},
#  {'job': 'Character Designer', 'name': 'Andrew Stanton'},
#  {'job': 'Character Designer', 'name': 'William Cone'},
#  {'job': 'Character Designer', 'name': 'Steve Johnson'},
#  {'job': 'Character Designer', 'name': 'Dan Haskett'},
#  {'job': 'Character Designer', 'name': 'Tom Holloway'},
#  {'job': 'Character Designer', 'name': 'Jean Gillmore'},
#  {'job': 'Layout', 'name': 'Desirée Mourad'},
#  {'job': 'Set Dresser', 'name': "Kelly O'Connell"},
#  {'job': 'Set Dresser', 'name': 'Sonoko Konishi'},
#  {'job': 'Set Dresser', 'name': 'Ann M. Rockwell'},
#  {'job': 'Editorial Manager', 'name': 'Julie M. McDonald'},
#  {'job': 'Assistant Editor', 'name': 'Robin Lee'},
#  {'job': 'Assistant Editor', 'name': 'Tom Freeman'},
#  {'job': 'Assistant Editor', 'name': 'Ada Cochavi'},
#  {'job': 'Assistant Editor', 'name': 'Dana Mulligan'},
#  {'job': 'Editorial Coordinator', 'name': 'Deirdre Morrison'},
#  {'job': 'Production Coordinator', 'name': 'Lori Lombardo'},
#  {'job': 'Production Coordinator', 'name': 'Ellen Devine'},
#  {'job': 'Unit Publicist', 'name': 'Lauren Beth Strogoff'},
#  {'job': 'Sound Re-Recording Mixer', 'name': 'Gary Rydstrom'},
#  {'job': 'Sound Re-Recording Mixer', 'name': 'Gary Summers'},
#  {'job': 'Supervising Sound Editor', 'name': 'Tim Holland'},
#  {'job': 'Sound Effects Editor', 'name': 'Pat Jackson'},
#  {'job': 'Sound Design Assistant', 'name': 'Tom Myers'},
#  {'job': 'Assistant Sound Editor', 'name': 'J.R. Grubbs'},
#  {'job': 'Assistant Sound Editor', 'name': 'Susan Sanford'},
#  {'job': 'Assistant Sound Editor', 'name': 'Susan Popovic'},
#  {'job': 'Assistant Sound Editor', 'name': 'Dan Engstrom'},
#  {'job': 'Casting Consultant', 'name': 'Ruth Lambert'},
#  {'job': 'ADR Voice Casting', 'name': 'Mickie McGowan'}]

# %%
df[df.original_title.str.contains('Les Mis')].head(1)
# Out:
#       adult                          genres original_language  original_title  \
# 1772  False  Crime, Drama, History, Romance                en  Les Misérables
#
#      popularity production_companies      production_countries release_date  \
# 1772  12.238488    Columbia Pictures  United States of America   1998-05-01
#
#          revenue            spoken_languages           title  vote_average  \
# 1772  14096321.0  English, Français, Español  Les Misérables           7.1
#
#       vote_count                                               cast  \
# 1772       157.0  [{'character': 'Jean Valjean', 'gender': 'm', ...
#
#                                                    crew
# 1772  [{'job': 'Director', 'name': 'Bille August'}, ...

# %%
filtered_df = df[(df['release_date'] >= '2012-01-01') & (df['release_date'] <= '2013-12-31')]

# %%
filtered_df[filtered_df.original_title.str.contains('Les Mis')].cast.values[0][0]['name']
# Out:
# 'Hugh Jackman'

# %%
filtered_df[filtered_df.original_title.str.contains('Silver Linings')].cast.values[0][1]['name']
# Out:
# 'Jennifer Lawrence'
