# %%
import pandas as pd

import json

with open('gg2013.json', 'r') as file:
    data = json.load(file)

# Convert the JSON data to a pandas DataFrame
df = pd.DataFrame(data)

# Extract user information into separate columns
df['user_screen_name'] = df['user'].apply(lambda x: x['screen_name'])
df['user_id'] = df['user'].apply(lambda x: x['id'])

# Drop the original 'user' column as we've extracted the needed information
df = df.drop('user', axis=1)

# Convert timestamp_ms to datetime
df['timestamp'] = pd.to_datetime(df['timestamp_ms'], unit='ms')

# Drop the original timestamp_ms column
df = df.drop('timestamp_ms', axis=1)

# Reorder columns for better readability
df = df[['id', 'timestamp', 'user_id', 'user_screen_name', 'text']]

# Display the first few rows of the DataFrame
# print(df.head())

# %%
import re

# Function to apply regex patterns and extract potential winners
def extract_winners(text, award):
    # Improved regex to properly handle 'just' variations
    just_variations = r'(?:(?:(?:she|he)\s+)?just\s+)?'
    winner_patterns = [
        r'(\w+(?:\s+\w+)?)\s+' + just_variations + r'wins\s+(?!' + award + ')',
        r'(\w+(?:\s+\w+)?)\s+' + just_variations + r'won\s+(?!' + award + ')',
        r'(\w+(?:\s+\w+)?)\s+' + just_variations + r'awarded\s+(?!' + award + ')',
        r'(\w+(?:\s+\w+)?)\s+' + just_variations + r'receives\s+(?!' + award + ')',
        r'(\w+(?:\s+\w+)?)\s+' + just_variations + r'received\s+(?!' + award + ')'
    ]
    winners = []
    for pattern in winner_patterns:
        matches = re.findall(pattern, text, re.IGNORECASE)
        winners.extend(matches)
    return winners

# Apply the extraction function to the 'text' column
df['potential_winners'] = df['text'].apply(lambda x: extract_winners(x, "Best Picture"))

# Print all non-NaN values in the potential_winners column
all_winners = df['potential_winners'].dropna()
winner_counts = {}
for winners in all_winners:
    if winners:  # Check if the list is not empty
        for winner in winners:
            if winner in winner_counts:
                winner_counts[winner] += 1
            else:
                winner_counts[winner] = 1

# Create the JSON structure
output = {
    "Award": "Best Picture",
    "Nominees": [],  # We don't have nominee information in the current data
    "Presenters": [],  # We don't have presenter information in the current data
    "Winner": [
        {
            "Name": winner,
            "Number of Tweets": count
        } for winner, count in winner_counts.items()
    ]
}

# Sort the winners by number of tweets in descending order
output["Winner"] = sorted(output["Winner"], key=lambda x: x["Number of Tweets"], reverse=True)

print(json.dumps(output, indent=4))
# Out:
# {
#     "Award": "Best Picture",
#     "Nominees": [],
#     "Presenters": [],
#     "Winner": [
#         {
#             "Name": "Ben Affleck",
#             "Number of Tweets": 286
#         },
#         {
#             "Name": "Anne Hathaway",
#             "Number of Tweets": 274
#         },
#         {
#             "Name": "Hugh Jackman",
#             "Number of Tweets": 239
#         },
#         {
#             "Name": "Jennifer Lawrence",
#             "Number of Tweets": 218
#         },
#         {
#             "Name": "Adele",
#             "Number of Tweets": 199
#         },
#         {
#             "Name": "when she",
#             "Number of Tweets": 187
#         },
#         {
#             "Name": "Christoph Waltz",
#             "Number of Tweets": 156
#         },
#         {
#             "Name": "Lewis",
#             "Number of Tweets": 130
#         },
#         {
#             "Name": "Lena Dunham",
#             "Number of Tweets": 128
#         },
#         {
#             "Name": "Claire Danes",
#             "Number of Tweets": 124
#         },
#         {
#             "Name": "Quentin Tarantino",
#             "Number of Tweets": 114
#         },
#         {
#             "Name": "Argo",
#             "Number of Tweets": 105
#         },
#         {
#             "Name": "Jessica Chastain",
#             "Number of Tweets": 100
#         },
#         {
#             "Name": "Les Miserables",
#             "Number of Tweets": 87
#         },
#         {
#             "Name": "picture is",
#             "Number of Tweets": 84
#         },
#         {
#             "Name": "should have",
#             "Number of Tweets": 79
#         },
#         {
#             "Name": "Wolverine just",
#             "Number of Tweets": 79
#         },
#         {
#             "Name": "Homeland",
#             "Number of Tweets": 70
#         },
#         {
#             "Name": "Maggie Smith",
#             "Number of Tweets": 69
#         },
#         {
#             "Name": "Don Cheadle",
#             "Number of Tweets": 63
#         },
#         {
#             "Name": "Brave",
#             "Number of Tweets": 62
#         },
#         {
#             "Name": "after she",
#             "Number of Tweets": 59
#         },
#         {
#             "Name": "GoldenGlobe",
#             "Number of Tweets": 54
#         },
#         {
#             "Name": "Girls",
#             "Number of Tweets": 49
#         },
#         {
#             "Name": "Julianne Moore",
#             "Number of Tweets": 48
#         },
#         {
#             "Name": "Damian Lewis",
#             "Number of Tweets": 48
#         },
#         {
#             "Name": "Kevin Costner",
#             "Number of Tweets": 46
#         },
#         {
#             "Name": "ve",
#             "Number of Tweets": 42
#         },
#         {
#             "Name": "goldenglobes",
#             "Number of Tweets": 39
#         },
#         {
#             "Name": "film is",
#             "Number of Tweets": 37
#         },
#         {
#             "Name": "Les Mis",
#             "Number of Tweets": 34
#         },
#         {
#             "Name": "Skyfall",
#             "Number of Tweets": 34
#         },
#         {
#             "Name": "Jodie Foster",
#             "Number of Tweets": 34
#         },
#         {
#             "Name": "Day Lewis",
#             "Number of Tweets": 33
#         },
#         {
#             "Name": "Amy Poehler",
#             "Number of Tweets": 32
#         },
#         {
#             "Name": "BenAffleck",
#             "Number of Tweets": 32
#         },
#         {
#             "Name": "Tarantino",
#             "Number of Tweets": 30
#         },
#         {
#             "Name": "god she",
#             "Number of Tweets": 25
#         },
#         {
#             "Name": "LesMiserables",
#             "Number of Tweets": 25
#         },
#         {
#             "Name": "Game Change",
#             "Number of Tweets": 24
#         },
#         {
#             "Name": "lenadunham",
#             "Number of Tweets": 24
#         },
#         {
#             "Name": "Paul Epworth",
#             "Number of Tweets": 22
#         },
#         {
#             "Name": "She",
#             "Number of Tweets": 21
#         },
#         {
#             "Name": "s",
#             "Number of Tweets": 19
#         },
#         {
#             "Name": "Bill Clinton",
#             "Number of Tweets": 19
#         },
#         {
#             "Name": "Ed Harris",
#             "Number of Tweets": 19
#         },
#         {
#             "Name": "OfficialAdele",
#             "Number of Tweets": 18
#         },
#         {
#             "Name": "GIRLS",
#             "Number of Tweets": 18
#         },
#         {
#             "Name": "of Pi",
#             "Number of Tweets": 17
#         },
#         {
#             "Name": "when Adele",
#             "Number of Tweets": 16
#         },
#         {
#             "Name": "is being",
#             "Number of Tweets": 16
#         },
#         {
#             "Name": "Justin Timberlake",
#             "Number of Tweets": 15
#         },
#         {
#             "Name": "Lawrence",
#             "Number of Tweets": 15
#         },
#         {
#             "Name": "Damien Lewis",
#             "Number of Tweets": 14
#         },
#         {
#             "Name": "by Adele",
#             "Number of Tweets": 14
#         },
#         {
#             "Name": "JenniferLawrence",
#             "Number of Tweets": 14
#         },
#         {
#             "Name": "Lawrence has",
#             "Number of Tweets": 13
#         },
#         {
#             "Name": "Poehler also",
#             "Number of Tweets": 13
#         },
#         {
#             "Name": "ARGO",
#             "Number of Tweets": 13
#         },
#         {
#             "Name": "LesMis",
#             "Number of Tweets": 13
#         },
#         {
#             "Name": "DjangoUnchained",
#             "Number of Tweets": 12
#         },
#         {
#             "Name": "Jackman has",
#             "Number of Tweets": 12
#         },
#         {
#             "Name": "Django",
#             "Number of Tweets": 11
#         },
#         {
#             "Name": "me who",
#             "Number of Tweets": 11
#         },
#         {
#             "Name": "has",
#             "Number of Tweets": 11
#         },
#         {
#             "Name": "LenaDunham",
#             "Number of Tweets": 11
#         },
#         {
#             "Name": "the room",
#             "Number of Tweets": 11
#         },
#         {
#             "Name": "Chastain has",
#             "Number of Tweets": 11
#         },
#         {
#             "Name": "I ever",
#             "Number of Tweets": 10
#         },
#         {
#             "Name": "have all",
#             "Number of Tweets": 10
#         },
#         {
#             "Name": "I just",
#             "Number of Tweets": 9
#         },
#         {
#             "Name": "Bill Murray",
#             "Number of Tweets": 9
#         },
#         {
#             "Name": "GameChange",
#             "Number of Tweets": 9
#         },
#         {
#             "Name": "GoldenGlobes And",
#             "Number of Tweets": 9
#         },
#         {
#             "Name": "who has",
#             "Number of Tweets": 9
#         },
#         {
#             "Name": "old boy",
#             "Number of Tweets": 9
#         },
#         {
#             "Name": "glad he",
#             "Number of Tweets": 9
#         },
#         {
#             "Name": "have ever",
#             "Number of Tweets": 9
#         },
#         {
#             "Name": "fucker that",
#             "Number of Tweets": 9
#         },
#         {
#             "Name": "have now",
#             "Number of Tweets": 9
#         },
#         {
#             "Name": "MaggieSmith",
#             "Number of Tweets": 8
#         },
#         {
#             "Name": "t",
#             "Number of Tweets": 8
#         },
#         {
#             "Name": "that Adele",
#             "Number of Tweets": 8
#         },
#         {
#             "Name": "from Skyfall",
#             "Number of Tweets": 8
#         },
#         {
#             "Name": "adele",
#             "Number of Tweets": 8
#         },
#         {
#             "Name": "mum Adele",
#             "Number of Tweets": 8
#         },
#         {
#             "Name": "glad Adele",
#             "Number of Tweets": 8
#         },
#         {
#             "Name": "85",
#             "Number of Tweets": 8
#         },
#         {
#             "Name": "Affleck",
#             "Number of Tweets": 8
#         },
#         {
#             "Name": "Ben affleck",
#             "Number of Tweets": 8
#         },
#         {
#             "Name": "LES MISERABLES",
#             "Number of Tweets": 8
#         },
#         {
#             "Name": "when he",
#             "Number of Tweets": 7
#         },
#         {
#             "Name": "has long",
#             "Number of Tweets": 7
#         },
#         {
#             "Name": "has now",
#             "Number of Tweets": 7
#         },
#         {
#             "Name": "know who",
#             "Number of Tweets": 7
#         },
#         {
#             "Name": "Mychael Danna",
#             "Number of Tweets": 7
#         },
#         {
#             "Name": "AnneHathaway",
#             "Number of Tweets": 7
#         },
#         {
#             "Name": "IamDonCheadle",
#             "Number of Tweets": 7
#         },
#         {
#             "Name": "Amour",
#             "Number of Tweets": 7
#         },
#         {
#             "Name": "happy they",
#             "Number of Tweets": 7
#         },
#         {
#             "Name": "GoldenGlobes director",
#             "Number of Tweets": 7
#         },
#         {
#             "Name": "all that",
#             "Number of Tweets": 7
#         },
#         {
#             "Name": "hope Adele",
#             "Number of Tweets": 6
#         },
#         {
#             "Name": "would have",
#             "Number of Tweets": 6
#         },
#         {
#             "Name": "if I",
#             "Number of Tweets": 6
#         },
#         {
#             "Name": "should of",
#             "Number of Tweets": 6
#         },
#         {
#             "Name": "Smith has",
#             "Number of Tweets": 6
#         },
#         {
#             "Name": "producers also",
#             "Number of Tweets": 6
#         },
#         {
#             "Name": "Adele even",
#             "Number of Tweets": 6
#         },
#         {
#             "Name": "Adele just",
#             "Number of Tweets": 6
#         },
#         {
#             "Name": "who",
#             "Number of Tweets": 6
#         },
#         {
#             "Name": "2013 ADELE",
#             "Number of Tweets": 6
#         },
#         {
#             "Name": "BRAVE",
#             "Number of Tweets": 6
#         },
#         {
#             "Name": "sure Amy",
#             "Number of Tweets": 6
#         },
#         {
#             "Name": "star",
#             "Number of Tweets": 6
#         },
#         {
#             "Name": "Le miz",
#             "Number of Tweets": 6
#         },
#         {
#             "Name": "Arog",
#             "Number of Tweets": 6
#         },
#         {
#             "Name": "Django Unchained",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "see who",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "Christopher Waltz",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "just",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "benaffleck",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "argo",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "Canada",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "ADELE",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "happy Adele",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "s Skyfall",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "Canadian",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "theme song",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "not have",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "as she",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "LES MIS",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "Quentin",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "may have",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "He",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "I",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "Lena",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "about who",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "Ben",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "girlsHBO",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "Hugh jackman",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "Les Miz",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "DanielDayLewis",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "The film",
#             "Number of Tweets": 5
#         },
#         {
#             "Name": "Linings Playbook",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "he",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "MAGGIE SMITH",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "HBO",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "_JulianneMoore",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "Waltz",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "Big early",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "Sarah Palin",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "lewis_damian",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "SHO_Homeland",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "s beard",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "it",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "guy who",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "glad she",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "Who",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "you",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "as Adele",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "Lee Jones",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "JENNIFER LAWRENCE",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "jennifer lawrence",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "Indiana just",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "GoldenGlobes",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "DJANGO",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "Bang Theory",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "Have them",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "LENADUNHAM",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "RealHughJackman",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "Wolverine",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "before she",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "happy Argo",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "and Argo",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "Takes Early",
#             "Number of Tweets": 4
#         },
#         {
#             "Name": "True Grit",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "has already",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Benedict Cumberbatch",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "he also",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "hope she",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "if Taylor",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Dowager Countess",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Katherine Bigelow",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "show that",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "You",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Julianna Moore",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "lesmiserables",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "glad it",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Who has",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "The show",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Hope Homeland",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Just",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "out who",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "and Adele",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Glad she",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "t have",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Lincoln",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Tay",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Lorne Michaels",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Law",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "way have",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Pi",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Jennifer",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "ANNE HATHAWAY",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Hathaway both",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "AMOUR",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "times and",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "ClaireDanes",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "that Brave",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Chicks never",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "BEN AFFLECK",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "from Mallrats",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Gigli has",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "CloseTiesDoc just",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "HUGH JACKMAN",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Singing Voice",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "why he",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "that it",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "BenAffleck Argo",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "Dominate TV",
#             "Number of Tweets": 3
#         },
#         {
#             "Name": "where she",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "We",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "but she",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Poehler",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "CHRISTOPH WALTZ",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "jango Unchained",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "all the",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Professor McGonagall",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "SofiaVergara",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Maggie smith",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "have already",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "So who",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "if she",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "because you",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "have both",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Modern Family",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "hope it",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Zeta Jones",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "should be",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "SHOULD HAVE",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "AHSFX",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Bryan Cranston",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Should have",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "of the",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "time something",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Danes has",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "of Homeland",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "HOMELAND",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Lewis has",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "les mis",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Of Pi",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "taylor swift",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "GoldenGlobes Adele",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "And Adele",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "VE",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Yay Adele",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "and she",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Glad Adele",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "EVEN ADELE",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "homeland",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Taylor Swift",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "cares who",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "glad Skyfall",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "she",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "KevinCostner",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "might have",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Will Ferrell",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "pretending she",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Katniss",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "My girl",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "JLaw",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "s goatee",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "when Homeland",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "PRINCESS MIA",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Palin finally",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "ANNE",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "GoldenGlobes just",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "She just",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Sally Field",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "pretend Hathaway",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "anne hathaway",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Hathaway",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "annehathaway",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "goldenglobes No",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Quagmire just",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Amanda Seyfried",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "QuentinTarantino",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "happy Quentin",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Cheadle",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Stallone",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Terrontino",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Michael Haneke",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Austria",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "QT",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "If Amour",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "If I",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Clare Danes",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Pixar",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Anne Hathway",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "ever not",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Brave just",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "amy poehler",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "and Girls",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Amy",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "best friend",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "LENA DUNHAM",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "s boobs",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Poehler still",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Pixar has",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Queen Madonna",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Anne Hatheway",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "if it",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "if Affleck",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "as he",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "He just",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Glad he",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "and yet",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "ben affleck",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "girls",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Girls just",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "s Girls",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Affleck has",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "the Year",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "that Girls",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "GIRLS just",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "These",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Any",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "show Girls",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Jackman who",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "SIX OH",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "HughJackman just",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "HughJackman",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Jackmon also",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "So Ben",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "and Wolverine",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "SilverLiningsPlaybook had",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "RevistaBillboard Adele",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "movies that",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "that he",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "DDL",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "JessicaChastain",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Daredevil all",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "many Gingers",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "everyone who",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Wow Argo",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Big",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "what films",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "glad Argo",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "nominated and",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "Daredevil",
#             "Number of Tweets": 2
#         },
#         {
#             "Name": "s bangs",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "fire she",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "you hope",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "scripted TV",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Kathryn Bigelow",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Dustin Hoffman",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "the patriots",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "RiseOfTheGuardians",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "dark thirty",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "facial hair",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Van Buren",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Pats",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Consolation",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "silver linings",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Amy have",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Tina Fey",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "care who",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "if leo",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "who actually",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Daniel Craig",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "CHRISTOPH",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "inglorious bastards",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Leonardo shoulda",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "be some",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Django already",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "t know",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "christoph waltz",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "first pick",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Django just",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "He only",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Leo Dicaprio",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "They just",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Christophe Waltz",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Christoph",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "actor alive",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "christoph Waltz",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "digitalgurl Djanjo",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Waltz has",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "she actually",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Cristoph Waltz",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "aunt Maggie",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "she never",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Smith always",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "people that",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "think she",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "happy Waltz",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "DiCaprio finally",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "christophwaltz",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Fritz",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Leo didnt",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Jared Leto",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "harrypotter",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Actress",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "MaggieSmith just",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "hope he",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "sarah paulson",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "asilentfilm",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "somehow also",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "downton",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "but never",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "HOPE LEONARDO",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "funny woman",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "course granmamma",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "ChristophterWaltz",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "the Hour",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "GAME CHANGE",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "yoshiki",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "game Change",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "They already",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Game change",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "t even",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Palin movie",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Woody Harrelson",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Andrew",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "with the",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Professor McGonnagall",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Glad it",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "that network",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "less who",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "llama el",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Gilmore Girls",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Jessica Lange",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "their movie",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Julianne",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Moore 2",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Julian Moore",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Smith who",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "JULIANNE MOORE",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "t be",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Fudge",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "and",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "QueenoftheRedheads",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "JulianneMoore",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Hugh Jacknan",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Well deserved",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "know you",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "now Julianne",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "musical always",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "SarahPalinUSA finally",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "who just",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "from Buffy",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "categories or",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Kate Hudson",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Walking Dead",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "when HBO",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "more British",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "ve both",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "juliannemoore",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "the Butcher",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "D shoulda",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "CMPunk had",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "when you",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "That lady",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Jeff Daniels",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Paul Rudd",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Someone",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "damienlewis just",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Homeland dude",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "he never",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "gingers have",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "A ginger",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "John Hamm",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "attention so",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "also who",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Steven Booshemmy",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Two redheads",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "So Homeland",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Brody",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "damien lewis",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Lewis also",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "PBSNature",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "why Homeland",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Bad have",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Love the",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "orchestrated The",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "accolades it",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "davidharewood Homeland",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "no",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "saying Taylor",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Newsroom missed",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "that HOMELAND",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "deserved Homeland",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "that Homeland",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "my timeline",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "are getting",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "DowntonAbbey",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "for future",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "who had",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "CIRCLE SHE",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "have totally",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "damienlewis",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "yay she",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "hope Argo",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Leo",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "dude never",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "pretending it",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "LifeOfPie",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "OF PI",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Jennifer Lopez",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Ang Lee",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "A CANADIAN",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "atlas had",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Michael Danna",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "guy that",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "GoldenGlobes Homeland",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "If you",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "bet Adele",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "fingers Madonna",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "dude who",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "The queen",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "if django",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Ew Adele",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "GoldenGlobes Skyfall",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Happy Skyfall",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "course Adele",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "YEEESSSSS ADELE",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Ninang Adele",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Yayyyy Adele",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "JLO just",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Go Adele",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Adele has",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "GIRL ADELE",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Word Adele",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "coarse Adele",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "surprised she",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Bond songs",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "that adele",
# ...
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Simpsons never",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "les mis\u00e9rables",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "LesMiserables has",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Comedy",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "It",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Hot Topic",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Mes has",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "second film",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "party Adele",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "The musical",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Chicago",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "hope bradley",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Grumpy Cat",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "and Mystique",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Fox",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "They have",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Miserables both",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "HBO Girls",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Les Mis\u00e9rables",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "patriots",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Whoever",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "GOD SHE",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Oona",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "book ever",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "my wife",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "tim allen",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "French movie",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "damian lewis",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Chastain",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "pretty much",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "personal favorite",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "s dress",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "motherfucker that",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "boobs that",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Hope she",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Lewis both",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "until she",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "jessicac",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "jessicachastain",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "lesmiz movie",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Clooney",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "why they",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Jennifer both",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "scenes that",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Miranda Kerr",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Morrissey",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Rob Lowe",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Jessica",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "ACTOR BREATHING",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "day lewis",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "jessica chastain",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Glee Cast",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "wud have",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Morrissey just",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Lewis finally",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "night DDL",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "DDL just",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "les miserables",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Acting just",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "A Brit",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Should of",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Chaistain  has",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Daniel DayLewis",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Salma Hayek",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "time fave",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Mystique all",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "And he",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "award he",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "lenadunham Girls",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "les Mis",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "jesicachastain",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "S PANTSUIT",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "if Argo",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "TAKEN 2",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "YESSSSSSSSSSSSSSSSSSSSSSSSSS ARGO",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "shld have",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "surprised Argo",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "their awards",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "QUENTIN NEVER",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "atunas1 Argo",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "goldenglobes Argo",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Folsdadddy she",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "And Argo",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "my choices",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "gzchef Argo",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "making movies",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "knew Argo",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "to his",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "CRAP ARGO",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "If ARGO",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "oscar nomination",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "of their",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "LES MISERABLE",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Mis fandom",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "and his",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "those who",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "many weird",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Argo just",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "PIERS MORGAN",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "which movie",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "and Poehler",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "bow tie",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Oscars but",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Leo had",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "your movie",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "hughjackman",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "sweep of",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Hoping it",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Cooper had",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Glad Ben",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Hugh",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "drama is",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "upset Argo",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Oscar snub",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "cmR43PDZ",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Otto never",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "about the",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "for her",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "fake movie",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Silverlinings playbook",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Glad Argo",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Chris Tucker",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "my girl",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "heard Lincoln",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "RealHughJackman has",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "and Jennifer",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Mitt Romney",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "actor has",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "those that",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "LEO FINALLY",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "and it",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "couple of",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "after they",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "hours of",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "those ones",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "craigzobel",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "My woman",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "if argo",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Leni Riefenstahl",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "and Django",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "hopes it",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "cuz it",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Gandhi school",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "stuff always",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "GIrls",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "feature diff",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "fiction",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "thrilled Affleck",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "that Argo",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "all his",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "each",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Chastain also",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "ve always",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "tweeted who",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "director and",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "L\u00e9s Mis\u00e9rables",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Claire Daines",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "and Dunham",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Waltz each",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "chrisveritas HOMELAND",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "the Pats",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "hoping Max",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "GoldenGlobes Argo",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Affleck also",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "Jon Hamm",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "If Argo",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "chriscolfer",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "at who",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "happy LesMis",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "have possibly",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "for ur",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "but they",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "OpG214Lb Adele",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "and Homeland",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "my guesses",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "happy ARGO",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "ZooeyDeschanel",
#             "Number of Tweets": 1
#         },
#         {
#             "Name": "hugh jackman",
#             "Number of Tweets": 1
#         }
#     ]
# }

# %% [markdown]
# assume nothing about outputs
#
# from winners list, identify candidates who fit type restrictions
#
# store in nominees - check against 2013 data

# %% [markdown]
# Type constraints:
# - eliminate pronouns, random phrases
#
# Goal(s):
# - Map entities to names/nicknames -> map should contain entity names in some standard format (First, Last)
# - Map entities to some quantity of popularity

# %% [markdown]
# Attempt at entity recognition from "winners" list

# %%
import spacy

winners = sorted(output["Winner"], key=lambda x: x["Number of Tweets"], reverse=True)

spacy_model = spacy.load('en_core_web_lg') # better entity recognition capability than en_core_web_sm

# {
#     Name : _,
#     Entities : []
# }
entity_list = []

for i in range(len(winners)):
    winner_name = winners[i]["Name"]
    spacy_output = spacy_model(winner_name)
    # print(f"spacy output: {spacy_output.ents}")
    # if spacy_output.ents == (): print("NO ENTITY IDENTIFIED")
    associated_entities = []
    for entity in spacy_output.ents:
        # print(f"entity:{entity}")
        # print([entity.text, entity.label_])
        # entity_list.append(entity.text)
        associated_entities.append(entity.text)
    
    name_entities = {
        "Name" : winner_name,
        "Entities" : associated_entities
    }
    
    entity_list.append(name_entities)
    

entity_list
# Out:
# [{'Name': 'Ben Affleck', 'Entities': ['Ben Affleck']},
#  {'Name': 'Anne Hathaway', 'Entities': ['Anne Hathaway']},
#  {'Name': 'Hugh Jackman', 'Entities': ['Hugh Jackman']},
#  {'Name': 'Jennifer Lawrence', 'Entities': ['Jennifer Lawrence']},
#  {'Name': 'Adele', 'Entities': ['Adele']},
#  {'Name': 'when she', 'Entities': []},
#  {'Name': 'Christoph Waltz', 'Entities': ['Christoph Waltz']},
#  {'Name': 'Lewis', 'Entities': []},
#  {'Name': 'Lena Dunham', 'Entities': ['Lena Dunham']},
#  {'Name': 'Claire Danes', 'Entities': ['Claire Danes']},
#  {'Name': 'Quentin Tarantino', 'Entities': ['Quentin Tarantino']},
#  {'Name': 'Argo', 'Entities': ['Argo']},
#  {'Name': 'Jessica Chastain', 'Entities': ['Jessica Chastain']},
#  {'Name': 'Les Miserables', 'Entities': ['Les Miserables']},
#  {'Name': 'picture is', 'Entities': []},
#  {'Name': 'should have', 'Entities': []},
#  {'Name': 'Wolverine just', 'Entities': ['Wolverine']},
#  {'Name': 'Homeland', 'Entities': []},
#  {'Name': 'Maggie Smith', 'Entities': ['Maggie Smith']},
#  {'Name': 'Don Cheadle', 'Entities': ['Don Cheadle']},
#  {'Name': 'Brave', 'Entities': []},
#  {'Name': 'after she', 'Entities': []},
#  {'Name': 'GoldenGlobe', 'Entities': ['GoldenGlobe']},
#  {'Name': 'Girls', 'Entities': []},
#  {'Name': 'Julianne Moore', 'Entities': ['Julianne Moore']},
#  {'Name': 'Damian Lewis', 'Entities': ['Damian Lewis']},
#  {'Name': 'Kevin Costner', 'Entities': ['Kevin Costner']},
#  {'Name': 've', 'Entities': []},
#  {'Name': 'goldenglobes', 'Entities': []},
#  {'Name': 'film is', 'Entities': []},
#  {'Name': 'Les Mis', 'Entities': ['Les Mis']},
#  {'Name': 'Skyfall', 'Entities': ['Skyfall']},
#  {'Name': 'Jodie Foster', 'Entities': ['Jodie Foster']},
#  {'Name': 'Day Lewis', 'Entities': []},
#  {'Name': 'Amy Poehler', 'Entities': ['Amy Poehler']},
#  {'Name': 'BenAffleck', 'Entities': ['BenAffleck']},
#  {'Name': 'Tarantino', 'Entities': ['Tarantino']},
#  {'Name': 'god she', 'Entities': []},
#  {'Name': 'LesMiserables', 'Entities': ['LesMiserables']},
#  {'Name': 'Game Change', 'Entities': []},
#  {'Name': 'lenadunham', 'Entities': []},
#  {'Name': 'Paul Epworth', 'Entities': ['Paul Epworth']},
#  {'Name': 'She', 'Entities': []},
#  {'Name': 's', 'Entities': []},
#  {'Name': 'Bill Clinton', 'Entities': ['Bill Clinton']},
#  {'Name': 'Ed Harris', 'Entities': ['Ed Harris']},
#  {'Name': 'OfficialAdele', 'Entities': []},
#  {'Name': 'GIRLS', 'Entities': []},
#  {'Name': 'of Pi', 'Entities': []},
#  {'Name': 'when Adele', 'Entities': ['Adele']},
#  {'Name': 'is being', 'Entities': []},
#  {'Name': 'Justin Timberlake', 'Entities': ['Justin Timberlake']},
#  {'Name': 'Lawrence', 'Entities': ['Lawrence']},
#  {'Name': 'Damien Lewis', 'Entities': ['Damien Lewis']},
#  {'Name': 'by Adele', 'Entities': ['Adele']},
#  {'Name': 'JenniferLawrence', 'Entities': ['JenniferLawrence']},
#  {'Name': 'Lawrence has', 'Entities': ['Lawrence']},
#  {'Name': 'Poehler also', 'Entities': ['Poehler']},
#  {'Name': 'ARGO', 'Entities': ['ARGO']},
#  {'Name': 'LesMis', 'Entities': ['LesMis']},
#  {'Name': 'DjangoUnchained', 'Entities': []},
#  {'Name': 'Jackman has', 'Entities': ['Jackman']},
#  {'Name': 'Django', 'Entities': ['Django']},
#  {'Name': 'me who', 'Entities': []},
#  {'Name': 'has', 'Entities': []},
#  {'Name': 'LenaDunham', 'Entities': ['LenaDunham']},
#  {'Name': 'the room', 'Entities': []},
#  {'Name': 'Chastain has', 'Entities': ['Chastain']},
#  {'Name': 'I ever', 'Entities': []},
#  {'Name': 'have all', 'Entities': []},
#  {'Name': 'I just', 'Entities': []},
#  {'Name': 'Bill Murray', 'Entities': ['Bill Murray']},
#  {'Name': 'GameChange', 'Entities': []},
#  {'Name': 'GoldenGlobes And', 'Entities': ['GoldenGlobes']},
#  {'Name': 'who has', 'Entities': []},
#  {'Name': 'old boy', 'Entities': []},
#  {'Name': 'glad he', 'Entities': []},
#  {'Name': 'have ever', 'Entities': []},
#  {'Name': 'fucker that', 'Entities': []},
#  {'Name': 'have now', 'Entities': []},
#  {'Name': 'MaggieSmith', 'Entities': []},
#  {'Name': 't', 'Entities': []},
#  {'Name': 'that Adele', 'Entities': ['Adele']},
#  {'Name': 'from Skyfall', 'Entities': ['Skyfall']},
#  {'Name': 'adele', 'Entities': ['adele']},
#  {'Name': 'mum Adele', 'Entities': ['Adele']},
#  {'Name': 'glad Adele', 'Entities': ['Adele']},
#  {'Name': '85', 'Entities': ['85']},
#  {'Name': 'Affleck', 'Entities': ['Affleck']},
#  {'Name': 'Ben affleck', 'Entities': ['Ben affleck']},
#  {'Name': 'LES MISERABLES', 'Entities': ['LES MISERABLES']},
#  {'Name': 'when he', 'Entities': []},
#  {'Name': 'has long', 'Entities': []},
#  {'Name': 'has now', 'Entities': []},
#  {'Name': 'know who', 'Entities': []},
#  {'Name': 'Mychael Danna', 'Entities': ['Mychael Danna']},
#  {'Name': 'AnneHathaway', 'Entities': ['AnneHathaway']},
#  {'Name': 'IamDonCheadle', 'Entities': []},
#  {'Name': 'Amour', 'Entities': []},
#  {'Name': 'happy they', 'Entities': []},
#  {'Name': 'GoldenGlobes director', 'Entities': ['GoldenGlobes']},
#  {'Name': 'all that', 'Entities': []},
#  {'Name': 'hope Adele', 'Entities': ['Adele']},
#  {'Name': 'would have', 'Entities': []},
#  {'Name': 'if I', 'Entities': []},
#  {'Name': 'should of', 'Entities': []},
#  {'Name': 'Smith has', 'Entities': ['Smith']},
#  {'Name': 'producers also', 'Entities': []},
#  {'Name': 'Adele even', 'Entities': ['Adele']},
#  {'Name': 'Adele just', 'Entities': ['Adele']},
#  {'Name': 'who', 'Entities': []},
#  {'Name': '2013 ADELE', 'Entities': ['2013']},
#  {'Name': 'BRAVE', 'Entities': []},
#  {'Name': 'sure Amy', 'Entities': ['Amy']},
#  {'Name': 'star', 'Entities': []},
#  {'Name': 'Le miz', 'Entities': []},
#  {'Name': 'Arog', 'Entities': []},
#  {'Name': 'Django Unchained', 'Entities': ['Django Unchained']},
#  {'Name': 'see who', 'Entities': []},
#  {'Name': 'Christopher Waltz', 'Entities': ['Christopher Waltz']},
#  {'Name': 'just', 'Entities': []},
#  {'Name': 'benaffleck', 'Entities': []},
#  {'Name': 'argo', 'Entities': ['argo']},
#  {'Name': 'Canada', 'Entities': ['Canada']},
#  {'Name': 'ADELE', 'Entities': ['ADELE']},
#  {'Name': 'happy Adele', 'Entities': ['Adele']},
#  {'Name': 's Skyfall', 'Entities': ['Skyfall']},
#  {'Name': 'Canadian', 'Entities': ['Canadian']},
#  {'Name': 'theme song', 'Entities': []},
#  {'Name': 'not have', 'Entities': []},
#  {'Name': 'as she', 'Entities': []},
#  {'Name': 'LES MIS', 'Entities': []},
#  {'Name': 'Quentin', 'Entities': ['Quentin']},
#  {'Name': 'may have', 'Entities': []},
#  {'Name': 'He', 'Entities': []},
#  {'Name': 'I', 'Entities': []},
#  {'Name': 'Lena', 'Entities': ['Lena']},
#  {'Name': 'about who', 'Entities': []},
#  {'Name': 'Ben', 'Entities': ['Ben']},
#  {'Name': 'girlsHBO', 'Entities': []},
#  {'Name': 'Hugh jackman', 'Entities': ['Hugh jackman']},
#  {'Name': 'Les Miz', 'Entities': ['Les Miz']},
#  {'Name': 'DanielDayLewis', 'Entities': []},
#  {'Name': 'The film', 'Entities': []},
#  {'Name': 'Linings Playbook', 'Entities': ['Linings Playbook']},
#  {'Name': 'he', 'Entities': []},
#  {'Name': 'MAGGIE SMITH', 'Entities': ['MAGGIE SMITH']},
#  {'Name': 'HBO', 'Entities': ['HBO']},
#  {'Name': '_JulianneMoore', 'Entities': []},
#  {'Name': 'Waltz', 'Entities': ['Waltz']},
#  {'Name': 'Big early', 'Entities': []},
#  {'Name': 'Sarah Palin', 'Entities': ['Sarah Palin']},
#  {'Name': 'lewis_damian', 'Entities': []},
#  {'Name': 'SHO_Homeland', 'Entities': []},
#  {'Name': 's beard', 'Entities': []},
#  {'Name': 'it', 'Entities': []},
#  {'Name': 'guy who', 'Entities': []},
#  {'Name': 'glad she', 'Entities': []},
#  {'Name': 'Who', 'Entities': []},
#  {'Name': 'you', 'Entities': []},
#  {'Name': 'as Adele', 'Entities': ['Adele']},
#  {'Name': 'Lee Jones', 'Entities': ['Lee Jones']},
#  {'Name': 'JENNIFER LAWRENCE', 'Entities': ['JENNIFER LAWRENCE']},
#  {'Name': 'jennifer lawrence', 'Entities': ['jennifer lawrence']},
#  {'Name': 'Indiana just', 'Entities': ['Indiana']},
#  {'Name': 'GoldenGlobes', 'Entities': ['GoldenGlobes']},
#  {'Name': 'DJANGO', 'Entities': []},
#  {'Name': 'Bang Theory', 'Entities': ['Bang Theory']},
#  {'Name': 'Have them', 'Entities': []},
#  {'Name': 'LENADUNHAM', 'Entities': ['LENADUNHAM']},
#  {'Name': 'RealHughJackman', 'Entities': []},
#  {'Name': 'Wolverine', 'Entities': ['Wolverine']},
#  {'Name': 'before she', 'Entities': []},
#  {'Name': 'happy Argo', 'Entities': ['Argo']},
#  {'Name': 'and Argo', 'Entities': ['Argo']},
#  {'Name': 'Takes Early', 'Entities': []},
#  {'Name': 'True Grit', 'Entities': []},
#  {'Name': 'has already', 'Entities': []},
#  {'Name': 'Benedict Cumberbatch', 'Entities': ['Benedict Cumberbatch']},
#  {'Name': 'he also', 'Entities': []},
#  {'Name': 'hope she', 'Entities': []},
#  {'Name': 'if Taylor', 'Entities': ['Taylor']},
#  {'Name': 'Dowager Countess', 'Entities': ['Dowager Countess']},
#  {'Name': 'Katherine Bigelow', 'Entities': ['Katherine Bigelow']},
#  {'Name': 'show that', 'Entities': []},
#  {'Name': 'You', 'Entities': []},
#  {'Name': 'Julianna Moore', 'Entities': ['Julianna Moore']},
#  {'Name': 'lesmiserables', 'Entities': ['lesmiserables']},
#  {'Name': 'glad it', 'Entities': []},
#  {'Name': 'Who has', 'Entities': []},
#  {'Name': 'The show', 'Entities': []},
#  {'Name': 'Hope Homeland', 'Entities': []},
#  {'Name': 'Just', 'Entities': []},
#  {'Name': 'out who', 'Entities': []},
#  {'Name': 'and Adele', 'Entities': ['Adele']},
#  {'Name': 'Glad she', 'Entities': []},
#  {'Name': 't have', 'Entities': []},
#  {'Name': 'Lincoln', 'Entities': ['Lincoln']},
#  {'Name': 'Tay', 'Entities': ['Tay']},
#  {'Name': 'Lorne Michaels', 'Entities': ['Lorne Michaels']},
#  {'Name': 'Law', 'Entities': []},
#  {'Name': 'way have', 'Entities': []},
#  {'Name': 'Pi', 'Entities': []},
#  {'Name': 'Jennifer', 'Entities': ['Jennifer']},
#  {'Name': 'ANNE HATHAWAY', 'Entities': ['ANNE HATHAWAY']},
#  {'Name': 'Hathaway both', 'Entities': ['Hathaway']},
#  {'Name': 'AMOUR', 'Entities': ['AMOUR']},
#  {'Name': 'times and', 'Entities': []},
#  {'Name': 'ClaireDanes', 'Entities': ['ClaireDanes']},
#  {'Name': 'that Brave', 'Entities': []},
#  {'Name': 'Chicks never', 'Entities': ['Chicks']},
#  {'Name': 'BEN AFFLECK', 'Entities': ['BEN AFFLECK']},
#  {'Name': 'from Mallrats', 'Entities': ['Mallrats']},
#  {'Name': 'Gigli has', 'Entities': ['Gigli']},
#  {'Name': 'CloseTiesDoc just', 'Entities': []},
#  {'Name': 'HUGH JACKMAN', 'Entities': ['HUGH JACKMAN']},
#  {'Name': 'Singing Voice', 'Entities': ['Singing Voice']},
#  {'Name': 'why he', 'Entities': []},
#  {'Name': 'that it', 'Entities': []},
#  {'Name': 'BenAffleck Argo', 'Entities': ['BenAffleck Argo']},
#  {'Name': 'Dominate TV', 'Entities': []},
#  {'Name': 'where she', 'Entities': []},
#  {'Name': 'We', 'Entities': []},
#  {'Name': 'but she', 'Entities': []},
#  {'Name': 'Poehler', 'Entities': ['Poehler']},
#  {'Name': 'CHRISTOPH WALTZ', 'Entities': ['CHRISTOPH WALTZ']},
#  {'Name': 'jango Unchained', 'Entities': []},
#  {'Name': 'all the', 'Entities': []},
#  {'Name': 'Professor McGonagall', 'Entities': ['McGonagall']},
#  {'Name': 'SofiaVergara', 'Entities': ['SofiaVergara']},
#  {'Name': 'Maggie smith', 'Entities': ['Maggie smith']},
#  {'Name': 'have already', 'Entities': []},
#  {'Name': 'So who', 'Entities': []},
#  {'Name': 'if she', 'Entities': []},
#  {'Name': 'because you', 'Entities': []},
#  {'Name': 'have both', 'Entities': []},
#  {'Name': 'Modern Family', 'Entities': ['Modern Family']},
#  {'Name': 'hope it', 'Entities': []},
#  {'Name': 'Zeta Jones', 'Entities': ['Zeta Jones']},
#  {'Name': 'should be', 'Entities': []},
#  {'Name': 'SHOULD HAVE', 'Entities': []},
#  {'Name': 'AHSFX', 'Entities': ['AHSFX']},
#  {'Name': 'Bryan Cranston', 'Entities': ['Bryan Cranston']},
#  {'Name': 'Should have', 'Entities': []},
#  {'Name': 'of the', 'Entities': []},
#  {'Name': 'time something', 'Entities': []},
#  {'Name': 'Danes has', 'Entities': ['Danes']},
#  {'Name': 'of Homeland', 'Entities': []},
#  {'Name': 'HOMELAND', 'Entities': ['HOMELAND']},
#  {'Name': 'Lewis has', 'Entities': []},
#  {'Name': 'les mis', 'Entities': []},
#  {'Name': 'Of Pi', 'Entities': []},
#  {'Name': 'taylor swift', 'Entities': ['taylor swift']},
#  {'Name': 'GoldenGlobes Adele', 'Entities': []},
#  {'Name': 'And Adele', 'Entities': ['Adele']},
#  {'Name': 'VE', 'Entities': []},
#  {'Name': 'Yay Adele', 'Entities': ['Adele']},
#  {'Name': 'and she', 'Entities': []},
#  {'Name': 'Glad Adele', 'Entities': ['Adele']},
#  {'Name': 'EVEN ADELE', 'Entities': []},
#  {'Name': 'homeland', 'Entities': []},
#  {'Name': 'Taylor Swift', 'Entities': ['Taylor Swift']},
#  {'Name': 'cares who', 'Entities': []},
#  {'Name': 'glad Skyfall', 'Entities': ['Skyfall']},
#  {'Name': 'she', 'Entities': []},
#  {'Name': 'KevinCostner', 'Entities': ['KevinCostner']},
#  {'Name': 'might have', 'Entities': []},
#  {'Name': 'Will Ferrell', 'Entities': ['Ferrell']},
#  {'Name': 'pretending she', 'Entities': []},
#  {'Name': 'Katniss', 'Entities': ['Katniss']},
#  {'Name': 'My girl', 'Entities': []},
#  {'Name': 'JLaw', 'Entities': []},
#  {'Name': 's goatee', 'Entities': []},
#  {'Name': 'when Homeland', 'Entities': []},
#  {'Name': 'PRINCESS MIA', 'Entities': []},
#  {'Name': 'Palin finally', 'Entities': ['Palin']},
#  {'Name': 'ANNE', 'Entities': []},
#  {'Name': 'GoldenGlobes just', 'Entities': []},
#  {'Name': 'She just', 'Entities': []},
#  {'Name': 'Sally Field', 'Entities': ['Sally Field']},
#  {'Name': 'pretend Hathaway', 'Entities': ['Hathaway']},
#  {'Name': 'anne hathaway', 'Entities': ['anne hathaway']},
#  {'Name': 'Hathaway', 'Entities': ['Hathaway']},
#  {'Name': 'annehathaway', 'Entities': []},
#  {'Name': 'goldenglobes No', 'Entities': []},
#  {'Name': 'Quagmire just', 'Entities': []},
#  {'Name': 'Amanda Seyfried', 'Entities': ['Amanda Seyfried']},
#  {'Name': 'QuentinTarantino', 'Entities': []},
#  {'Name': 'happy Quentin', 'Entities': ['Quentin']},
#  {'Name': 'Cheadle', 'Entities': ['Cheadle']},
#  {'Name': 'Stallone', 'Entities': ['Stallone']},
#  {'Name': 'Terrontino', 'Entities': []},
#  {'Name': 'Michael Haneke', 'Entities': ['Michael Haneke']},
#  {'Name': 'Austria', 'Entities': ['Austria']},
#  {'Name': 'QT', 'Entities': ['QT']},
#  {'Name': 'If Amour', 'Entities': []},
#  {'Name': 'If I', 'Entities': []},
#  {'Name': 'Clare Danes', 'Entities': ['Clare Danes']},
#  {'Name': 'Pixar', 'Entities': ['Pixar']},
#  {'Name': 'Anne Hathway', 'Entities': ['Anne Hathway']},
#  {'Name': 'ever not', 'Entities': []},
#  {'Name': 'Brave just', 'Entities': []},
#  {'Name': 'amy poehler', 'Entities': ['amy poehler']},
#  {'Name': 'and Girls', 'Entities': []},
#  {'Name': 'Amy', 'Entities': ['Amy']},
#  {'Name': 'best friend', 'Entities': []},
#  {'Name': 'LENA DUNHAM', 'Entities': ['LENA DUNHAM']},
#  {'Name': 's boobs', 'Entities': []},
#  {'Name': 'Poehler still', 'Entities': ['Poehler']},
#  {'Name': 'Pixar has', 'Entities': ['Pixar']},
#  {'Name': 'Queen Madonna', 'Entities': ['Madonna']},
#  {'Name': 'Anne Hatheway', 'Entities': ['Anne Hatheway']},
#  {'Name': 'if it', 'Entities': []},
#  {'Name': 'if Affleck', 'Entities': ['Affleck']},
#  {'Name': 'as he', 'Entities': []},
#  {'Name': 'He just', 'Entities': []},
#  {'Name': 'Glad he', 'Entities': []},
#  {'Name': 'and yet', 'Entities': []},
#  {'Name': 'ben affleck', 'Entities': ['ben affleck']},
#  {'Name': 'girls', 'Entities': []},
#  {'Name': 'Girls just', 'Entities': []},
#  {'Name': 's Girls', 'Entities': []},
#  {'Name': 'Affleck has', 'Entities': ['Affleck']},
#  {'Name': 'the Year', 'Entities': []},
#  {'Name': 'that Girls', 'Entities': ['Girls']},
#  {'Name': 'GIRLS just', 'Entities': []},
#  {'Name': 'These', 'Entities': []},
#  {'Name': 'Any', 'Entities': []},
#  {'Name': 'show Girls', 'Entities': []},
#  {'Name': 'Jackman who', 'Entities': ['Jackman']},
#  {'Name': 'SIX OH', 'Entities': ['SIX']},
#  {'Name': 'HughJackman just', 'Entities': ['HughJackman']},
#  {'Name': 'HughJackman', 'Entities': ['HughJackman']},
#  {'Name': 'Jackmon also', 'Entities': ['Jackmon']},
#  {'Name': 'So Ben', 'Entities': ['Ben']},
#  {'Name': 'and Wolverine', 'Entities': ['Wolverine']},
#  {'Name': 'SilverLiningsPlaybook had', 'Entities': ['SilverLiningsPlaybook']},
#  {'Name': 'RevistaBillboard Adele', 'Entities': ['RevistaBillboard']},
#  {'Name': 'movies that', 'Entities': []},
#  {'Name': 'that he', 'Entities': []},
#  {'Name': 'DDL', 'Entities': []},
#  {'Name': 'JessicaChastain', 'Entities': []},
#  {'Name': 'Daredevil all', 'Entities': []},
#  {'Name': 'many Gingers', 'Entities': ['Gingers']},
#  {'Name': 'everyone who', 'Entities': []},
#  {'Name': 'Wow Argo', 'Entities': ['Argo']},
#  {'Name': 'Big', 'Entities': []},
#  {'Name': 'what films', 'Entities': []},
#  {'Name': 'glad Argo', 'Entities': ['Argo']},
#  {'Name': 'nominated and', 'Entities': []},
#  {'Name': 'Daredevil', 'Entities': []},
#  {'Name': 's bangs', 'Entities': []},
#  {'Name': 'fire she', 'Entities': []},
#  {'Name': 'you hope', 'Entities': []},
#  {'Name': 'scripted TV', 'Entities': []},
#  {'Name': 'Kathryn Bigelow', 'Entities': ['Kathryn Bigelow']},
#  {'Name': 'Dustin Hoffman', 'Entities': ['Dustin Hoffman']},
#  {'Name': 'the patriots', 'Entities': []},
#  {'Name': 'RiseOfTheGuardians', 'Entities': ['RiseOfTheGuardians']},
#  {'Name': 'dark thirty', 'Entities': ['thirty']},
#  {'Name': 'facial hair', 'Entities': []},
#  {'Name': 'Van Buren', 'Entities': ['Van Buren']},
#  {'Name': 'Pats', 'Entities': []},
#  {'Name': 'Consolation', 'Entities': []},
#  {'Name': 'silver linings', 'Entities': []},
#  {'Name': 'Amy have', 'Entities': ['Amy']},
#  {'Name': 'Tina Fey', 'Entities': ['Tina Fey']},
#  {'Name': 'care who', 'Entities': []},
#  {'Name': 'if leo', 'Entities': ['leo']},
#  {'Name': 'who actually', 'Entities': []},
#  {'Name': 'Daniel Craig', 'Entities': ['Daniel Craig']},
#  {'Name': 'CHRISTOPH', 'Entities': ['CHRISTOPH']},
#  {'Name': 'inglorious bastards', 'Entities': []},
#  {'Name': 'Leonardo shoulda', 'Entities': ['Leonardo']},
#  {'Name': 'be some', 'Entities': []},
#  {'Name': 'Django already', 'Entities': ['Django']},
#  {'Name': 't know', 'Entities': []},
#  {'Name': 'christoph waltz', 'Entities': ['christoph waltz']},
#  {'Name': 'first pick', 'Entities': ['first']},
#  {'Name': 'Django just', 'Entities': []},
#  {'Name': 'He only', 'Entities': []},
#  {'Name': 'Leo Dicaprio', 'Entities': ['Leo Dicaprio']},
#  {'Name': 'They just', 'Entities': []},
#  {'Name': 'Christophe Waltz', 'Entities': ['Christophe Waltz']},
#  {'Name': 'Christoph', 'Entities': ['Christoph']},
#  {'Name': 'actor alive', 'Entities': []},
#  {'Name': 'christoph Waltz', 'Entities': ['christoph Waltz']},
#  {'Name': 'digitalgurl Djanjo', 'Entities': ['Djanjo']},
#  {'Name': 'Waltz has', 'Entities': ['Waltz']},
#  {'Name': 'she actually', 'Entities': []},
#  {'Name': 'Cristoph Waltz', 'Entities': ['Cristoph Waltz']},
#  {'Name': 'aunt Maggie', 'Entities': ['Maggie']},
#  {'Name': 'she never', 'Entities': []},
#  {'Name': 'Smith always', 'Entities': ['Smith']},
#  {'Name': 'people that', 'Entities': []},
#  {'Name': 'think she', 'Entities': []},
#  {'Name': 'happy Waltz', 'Entities': ['Waltz']},
#  {'Name': 'DiCaprio finally', 'Entities': ['DiCaprio']},
#  {'Name': 'christophwaltz', 'Entities': []},
#  {'Name': 'Fritz', 'Entities': ['Fritz']},
#  {'Name': 'Leo didnt', 'Entities': ['Leo']},
#  {'Name': 'Jared Leto', 'Entities': ['Jared Leto']},
#  {'Name': 'harrypotter', 'Entities': []},
#  {'Name': 'Actress', 'Entities': []},
#  {'Name': 'MaggieSmith just', 'Entities': []},
#  {'Name': 'hope he', 'Entities': []},
#  {'Name': 'sarah paulson', 'Entities': ['sarah paulson']},
#  {'Name': 'asilentfilm', 'Entities': []},
#  {'Name': 'somehow also', 'Entities': []},
#  {'Name': 'downton', 'Entities': []},
#  {'Name': 'but never', 'Entities': []},
#  {'Name': 'HOPE LEONARDO', 'Entities': ['LEONARDO']},
#  {'Name': 'funny woman', 'Entities': []},
#  {'Name': 'course granmamma', 'Entities': []},
#  {'Name': 'ChristophterWaltz', 'Entities': ['ChristophterWaltz']},
#  {'Name': 'the Hour', 'Entities': []},
#  {'Name': 'GAME CHANGE', 'Entities': []},
#  {'Name': 'yoshiki', 'Entities': ['yoshiki']},
#  {'Name': 'game Change', 'Entities': []},
#  {'Name': 'They already', 'Entities': []},
#  {'Name': 'Game change', 'Entities': []},
#  {'Name': 't even', 'Entities': []},
#  {'Name': 'Palin movie', 'Entities': ['Palin']},
#  {'Name': 'Woody Harrelson', 'Entities': ['Woody Harrelson']},
#  {'Name': 'Andrew', 'Entities': ['Andrew']},
#  {'Name': 'with the', 'Entities': []},
#  {'Name': 'Professor McGonnagall', 'Entities': ['McGonnagall']},
#  {'Name': 'Glad it', 'Entities': []},
#  {'Name': 'that network', 'Entities': []},
#  {'Name': 'less who', 'Entities': []},
#  {'Name': 'llama el', 'Entities': []},
#  {'Name': 'Gilmore Girls', 'Entities': ['Gilmore']},
#  {'Name': 'Jessica Lange', 'Entities': ['Jessica Lange']},
#  {'Name': 'their movie', 'Entities': []},
#  {'Name': 'Julianne', 'Entities': ['Julianne']},
#  {'Name': 'Moore 2', 'Entities': ['2']},
#  {'Name': 'Julian Moore', 'Entities': ['Julian Moore']},
#  {'Name': 'Smith who', 'Entities': ['Smith']},
#  {'Name': 'JULIANNE MOORE', 'Entities': ['JULIANNE MOORE']},
#  {'Name': 't be', 'Entities': []},
#  {'Name': 'Fudge', 'Entities': []},
#  {'Name': 'and', 'Entities': []},
#  {'Name': 'QueenoftheRedheads', 'Entities': ['QueenoftheRedheads']},
#  {'Name': 'JulianneMoore', 'Entities': ['JulianneMoore']},
#  {'Name': 'Hugh Jacknan', 'Entities': ['Hugh Jacknan']},
#  {'Name': 'Well deserved', 'Entities': []},
#  {'Name': 'know you', 'Entities': []},
#  {'Name': 'now Julianne', 'Entities': ['Julianne']},
#  {'Name': 'musical always', 'Entities': []},
#  {'Name': 'SarahPalinUSA finally', 'Entities': []},
#  {'Name': 'who just', 'Entities': []},
#  {'Name': 'from Buffy', 'Entities': []},
#  {'Name': 'categories or', 'Entities': []},
#  {'Name': 'Kate Hudson', 'Entities': ['Kate Hudson']},
#  {'Name': 'Walking Dead', 'Entities': []},
#  {'Name': 'when HBO', 'Entities': ['HBO']},
#  {'Name': 'more British', 'Entities': ['British']},
#  {'Name': 've both', 'Entities': []},
#  {'Name': 'juliannemoore', 'Entities': []},
#  {'Name': 'the Butcher', 'Entities': ['Butcher']},
#  {'Name': 'D shoulda', 'Entities': []},
#  {'Name': 'CMPunk had', 'Entities': ['CMPunk']},
#  {'Name': 'when you', 'Entities': []},
#  {'Name': 'That lady', 'Entities': []},
#  {'Name': 'Jeff Daniels', 'Entities': ['Jeff Daniels']},
#  {'Name': 'Paul Rudd', 'Entities': ['Paul Rudd']},
#  {'Name': 'Someone', 'Entities': []},
#  {'Name': 'damienlewis just', 'Entities': []},
#  {'Name': 'Homeland dude', 'Entities': []},
#  {'Name': 'he never', 'Entities': []},
#  {'Name': 'gingers have', 'Entities': []},
#  {'Name': 'A ginger', 'Entities': []},
#  {'Name': 'John Hamm', 'Entities': ['John Hamm']},
#  {'Name': 'attention so', 'Entities': []},
#  {'Name': 'also who', 'Entities': []},
#  {'Name': 'Steven Booshemmy', 'Entities': ['Steven Booshemmy']},
#  {'Name': 'Two redheads', 'Entities': ['Two']},
#  {'Name': 'So Homeland', 'Entities': []},
#  {'Name': 'Brody', 'Entities': ['Brody']},
#  {'Name': 'damien lewis', 'Entities': ['damien lewis']},
#  {'Name': 'Lewis also', 'Entities': []},
#  {'Name': 'PBSNature', 'Entities': []},
#  {'Name': 'why Homeland', 'Entities': []},
#  {'Name': 'Bad have', 'Entities': []},
#  {'Name': 'Love the', 'Entities': []},
#  {'Name': 'orchestrated The', 'Entities': []},
#  {'Name': 'accolades it', 'Entities': []},
#  {'Name': 'davidharewood Homeland', 'Entities': []},
#  {'Name': 'no', 'Entities': []},
#  {'Name': 'saying Taylor', 'Entities': ['Taylor']},
#  {'Name': 'Newsroom missed', 'Entities': ['Newsroom']},
#  {'Name': 'that HOMELAND', 'Entities': ['HOMELAND']},
#  {'Name': 'deserved Homeland', 'Entities': []},
#  {'Name': 'that Homeland', 'Entities': ['Homeland']},
#  {'Name': 'my timeline', 'Entities': []},
#  {'Name': 'are getting', 'Entities': []},
#  {'Name': 'DowntonAbbey', 'Entities': ['DowntonAbbey']},
#  {'Name': 'for future', 'Entities': []},
#  {'Name': 'who had', 'Entities': []},
#  {'Name': 'CIRCLE SHE', 'Entities': []},
#  {'Name': 'have totally', 'Entities': []},
#  {'Name': 'damienlewis', 'Entities': []},
#  {'Name': 'yay she', 'Entities': []},
#  {'Name': 'hope Argo', 'Entities': ['Argo']},
#  {'Name': 'Leo', 'Entities': ['Leo']},
#  {'Name': 'dude never', 'Entities': []},
#  {'Name': 'pretending it', 'Entities': []},
#  {'Name': 'LifeOfPie', 'Entities': ['LifeOfPie']},
#  {'Name': 'OF PI', 'Entities': ['PI']},
#  {'Name': 'Jennifer Lopez', 'Entities': ['Jennifer Lopez']},
#  {'Name': 'Ang Lee', 'Entities': ['Ang Lee']},
#  {'Name': 'A CANADIAN', 'Entities': ['CANADIAN']},
#  {'Name': 'atlas had', 'Entities': ['atlas']},
#  {'Name': 'Michael Danna', 'Entities': ['Michael Danna']},
#  {'Name': 'guy that', 'Entities': []},
#  {'Name': 'GoldenGlobes Homeland', 'Entities': []},
#  {'Name': 'If you', 'Entities': []},
#  {'Name': 'bet Adele', 'Entities': ['Adele']},
#  {'Name': 'fingers Madonna', 'Entities': ['Madonna']},
#  {'Name': 'dude who', 'Entities': []},
#  {'Name': 'The queen', 'Entities': []},
#  {'Name': 'if django', 'Entities': []},
#  {'Name': 'Ew Adele', 'Entities': []},
#  {'Name': 'GoldenGlobes Skyfall', 'Entities': ['GoldenGlobes Skyfall']},
#  {'Name': 'Happy Skyfall', 'Entities': ['Skyfall']},
#  {'Name': 'course Adele', 'Entities': ['Adele']},
#  {'Name': 'YEEESSSSS ADELE', 'Entities': ['YEEESSSSS ADELE']},
#  {'Name': 'Ninang Adele', 'Entities': ['Ninang Adele']},
#  {'Name': 'Yayyyy Adele', 'Entities': []},
#  {'Name': 'JLO just', 'Entities': ['JLO']},
#  {'Name': 'Go Adele', 'Entities': ['Adele']},
#  {'Name': 'Adele has', 'Entities': ['Adele']},
#  {'Name': 'GIRL ADELE', 'Entities': []},
#  {'Name': 'Word Adele', 'Entities': ['Adele']},
#  {'Name': 'coarse Adele', 'Entities': ['Adele']},
#  {'Name': 'surprised she', 'Entities': []},
#  {'Name': 'Bond songs', 'Entities': []},
#  {'Name': 'that adele', 'Entities': ['adele']},
#  {'Name': 'Sound still', 'Entities': []},
#  {'Name': 'Ahh Adele', 'Entities': []},
#  {'Name': 'Oh Adele', 'Entities': ['Adele']},
#  {'Name': 'Fat Amy', 'Entities': []},
#  {'Name': 'song that', 'Entities': []},
#  {'Name': 'singer Adele', 'Entities': ['Adele']},
#  {'Name': 'SKYFALL', 'Entities': ['SKYFALL']},
#  {'Name': 'SHE', 'Entities': []},
#  {'Name': 'whenever she', 'Entities': []},
#  {'Name': 'one who', 'Entities': []},
#  {'Name': 'after Adele', 'Entities': ['Adele']},
#  {'Name': 'so Adele', 'Entities': ['Adele']},
#  {'Name': 'conductor shoulda', 'Entities': []},
#  {'Name': 'james bond', 'Entities': ['james bond']},
#  {'Name': 'Swift had', 'Entities': []},
#  {'Name': 'SkyFall', 'Entities': ['SkyFall']},
#  {'Name': 'Obviously Adele', 'Entities': ['Adele']},
#  {'Name': 'But I', 'Entities': []},
#  {'Name': 'when  Adele', 'Entities': ['Adele']},
#  {'Name': 'Hypable Adele', 'Entities': []},
#  {'Name': 'yPLzpLND Adele', 'Entities': ['Adele']},
#  {'Name': 'GUESS ADELE', 'Entities': []},
#  {'Name': 'show itself', 'Entities': []},
#  {'Name': 'If Adele', 'Entities': ['Adele']},
#  {'Name': 'When she', 'Entities': []},
#  {'Name': 'Yeah Adele', 'Entities': ['Adele']},
#  {'Name': 'JAMES BOND', 'Entities': ['JAMES BOND']},
#  {'Name': 'and unloved', 'Entities': []},
#  {'Name': 'named Simon', 'Entities': ['Simon']},
#  {'Name': 'TVGuide Adele', 'Entities': ['Adele']},
#  {'Name': 'This lady', 'Entities': []},
#  {'Name': 'Jason Statham', 'Entities': ['Jason Statham']},
#  {'Name': 'to back', 'Entities': []},
#  {'Name': 'officialAdele', 'Entities': []},
#  {'Name': 'officaladele', 'Entities': []},
#  {'Name': 'hearing she', 'Entities': []},
#  {'Name': 'Doubtfire just', 'Entities': ['Doubtfire']},
#  {'Name': 'monitor who', 'Entities': []},
#  {'Name': 'skyfall rightfully', 'Entities': ['skyfall']},
#  {'Name': 'skyfall', 'Entities': ['skyfall']},
#  {'Name': 'Lewis only', 'Entities': []},
#  {'Name': 'Adelle who', 'Entities': ['Adelle']},
#  {'Name': 've totally', 'Entities': []},
#  {'Name': 'whn she', 'Entities': []},
#  {'Name': 'Jessica Alba', 'Entities': ['Jessica Alba']},
#  {'Name': 'riseoftheguardians', 'Entities': []},
#  {'Name': 'Adèle', 'Entities': ['Adèle']},
#  {'Name': 'because JLo', 'Entities': ['JLo']},
#  {'Name': 'Kevin Coatner', 'Entities': ['Kevin Coatner']},
#  {'Name': 'Water World', 'Entities': []},
#  {'Name': 'emwatson Maggie', 'Entities': ['Maggie']},
#  {'Name': 'her who', 'Entities': []},
#  {'Name': 'wished he', 'Entities': []},
#  {'Name': 'sons and', 'Entities': []},
#  {'Name': 'KEVIN COSTNER', 'Entities': ['KEVIN COSTNER']},
#  {'Name': '1991 he', 'Entities': ['1991']},
#  {'Name': 'when adele', 'Entities': ['adele']},
#  {'Name': 'Last', 'Entities': []},
#  {'Name': 'times Costner', 'Entities': ['Costner']},
#  {'Name': 'not only', 'Entities': []},
#  {'Name': 'but Adele', 'Entities': ['Adele']},
#  {'Name': 'HAVE BOTH', 'Entities': []},
#  {'Name': 'Obama already', 'Entities': ['Obama']},
#  {'Name': 'have each', 'Entities': []},
#  {'Name': 'The series', 'Entities': []},
#  {'Name': 'BILL CLINTON', 'Entities': ['BILL CLINTON']},
#  {'Name': 'Costner has', 'Entities': ['Costner']},
#  {'Name': 'jessica alba', 'Entities': ['jessica alba']},
#  {'Name': 'HatfieldsandMcCoys  Last', 'Entities': []},
#  {'Name': 'jerrycferrara \nAdele', 'Entities': ['jerrycferrara \n', 'Adele']},
#  {'Name': 'Sound shouldda', 'Entities': []},
#  {'Name': 'glorious Adele', 'Entities': ['Adele']},
#  {'Name': 'AUDREY HEPBURN', 'Entities': ['AUDREY HEPBURN']},
#  {'Name': 'her career', 'Entities': []},
#  {'Name': 'Clinton', 'Entities': ['Clinton']},
#  {'Name': 'hands down', 'Entities': []},
#  {'Name': 'out and', 'Entities': []},
#  {'Name': 'have i', 'Entities': []},
#  {'Name': 'and DDL', 'Entities': []},
#  {'Name': 'where that', 'Entities': []},
#  {'Name': 'R2D2', 'Entities': ['R2D2']},
#  {'Name': 'Swift shoulda', 'Entities': []},
#  {'Name': 'Improv', 'Entities': ['Improv']},
#  {'Name': 'Will Feral', 'Entities': []},
#  {'Name': 'Meryl Streep', 'Entities': ['Meryl Streep']},
#  {'Name': 'Kevin Cosner', 'Entities': ['Kevin Cosner']},
#  {'Name': 'Skyfall just', 'Entities': ['Skyfall']},
#  {'Name': 'Lawrence bipolar', 'Entities': ['Lawrence']},
#  {'Name': 'you just', 'Entities': []},
#  {'Name': 'JLAW', 'Entities': []},
#  {'Name': 'Jennifer Kawrence', 'Entities': ['Jennifer Kawrence']},
#  {'Name': 'Kristin Wiig', 'Entities': ['Kristin Wiig']},
#  {'Name': 'Clinton automatically', 'Entities': ['Clinton']},
#  {'Name': '22 and', 'Entities': ['22']},
#  {'Name': 'linings playbook', 'Entities': []},
#  {'Name': 'yea Adele', 'Entities': ['Adele']},
#  {'Name': 'ferrels mustache', 'Entities': ['ferrels']},
#  {'Name': 'hunger game', 'Entities': []},
#  {'Name': 'Jennifer Laweance', 'Entities': ['Jennifer Laweance']},
#  {'Name': 'Kirsten Wiig', 'Entities': ['Kirsten Wiig']},
#  {'Name': 'never watched', 'Entities': []},
#  {'Name': 'LINCOLN definitely', 'Entities': ['LINCOLN']},
#  {'Name': 'ever have', 'Entities': []},
#  {'Name': 'Katniss Everdeen', 'Entities': ['Katniss Everdeen']},
#  {'Name': 'that JLaw', 'Entities': []},
#  {'Name': 'but Mario', 'Entities': ['Mario']},
#  {'Name': 'know adele', 'Entities': ['adele']},
#  {'Name': 'sure she', 'Entities': []},
#  {'Name': 'when someone', 'Entities': []},
#  {'Name': 'reason she', 'Entities': []},
#  {'Name': 'that Jennifer', 'Entities': ['Jennifer']},
#  {'Name': 'young and', 'Entities': []},
#  {'Name': 'Jennifer Lawernce', 'Entities': ['Jennifer Lawernce']},
#  {'Name': 'Hill still', 'Entities': ['Hill']},
#  {'Name': 'Chris Colfer', 'Entities': ['Chris Colfer']},
#  {'Name': 'Mandy Patinkin', 'Entities': ['Mandy Patinkin']},
#  {'Name': 'for sure', 'Entities': []},
#  {'Name': 'Andrew McCutchen', 'Entities': ['Andrew McCutchen']},
#  {'Name': 'heart you', 'Entities': []},
#  {'Name': 'if Michelle', 'Entities': ['Michelle']},
#  {'Name': 'DREAM SHE', 'Entities': []},
#  {'Name': 'And she', 'Entities': []},
#  {'Name': 'Casper Smart', 'Entities': ['Casper Smart']},
#  {'Name': 'hair and', 'Entities': []},
#  {'Name': 'Faye Dunaway', 'Entities': ['Faye Dunaway']},
#  {'Name': 'never', 'Entities': []},
#  {'Name': 'Breaking Bad', 'Entities': []},
#  {'Name': 'anne hatheway', 'Entities': ['anne hatheway']},
#  {'Name': 'that you', 'Entities': []},
#  {'Name': 'They both', 'Entities': []},
#  {'Name': 'John Krasinski', 'Entities': ['John Krasinski']},
#  {'Name': 'but', 'Entities': []},
#  {'Name': 'Anne', 'Entities': []},
#  {'Name': 'Jennifer chick', 'Entities': ['Jennifer']},
#  {'Name': 'for who', 'Entities': []},
#  {'Name': 'Liza Minnelli', 'Entities': ['Liza Minnelli']},
#  {'Name': 'and pestilence', 'Entities': []},
#  {'Name': 'many more', 'Entities': []},
#  {'Name': 'Amne Hathaway', 'Entities': ['Amne Hathaway']},
#  {'Name': 'acts like', 'Entities': []},
#  {'Name': 'then Catwoman', 'Entities': ['Catwoman']},
#  {'Name': 'Genovia and', 'Entities': ['Genovia']},
#  {'Name': 'Field wouldve', 'Entities': []},
#  {'Name': 'surprised I', 'Entities': []},
#  {'Name': 'its like', 'Entities': []},
#  {'Name': 'been all', 'Entities': []},
#  {'Name': 'girl Anne', 'Entities': []},
#  {'Name': 'Princess mia', 'Entities': []},
#  {'Name': 'THAT JLAW', 'Entities': []},
#  {'Name': 'WHEN GLEE', 'Entities': []},
#  {'Name': 'Hathaway to', 'Entities': ['Hathaway']},
#  {'Name': 'thinks she', 'Entities': []},
#  {'Name': 'and McCoys', 'Entities': ['McCoys']},
#  {'Name': 'my baby', 'Entities': []},
#  {'Name': 'AnnHathaway', 'Entities': ['AnnHathaway']},
#  {'Name': 'Tarantino also', 'Entities': ['Tarantino']},
#  {'Name': 'Herman Munster', 'Entities': ['Herman Munster']},
#  {'Name': 'YES YOU', 'Entities': []},
#  {'Name': 'no surprise', 'Entities': []},
#  {'Name': 'Quintin', 'Entities': ['Quintin']},
#  {'Name': 'homeless guy', 'Entities': []},
#  {'Name': 'time Django', 'Entities': ['Django']},
#  {'Name': 'sure you', 'Entities': []},
#  {'Name': 'And Quentin', 'Entities': ['Quentin']},
#  {'Name': 'Quentin Tarratino', 'Entities': ['Quentin Tarratino']},
#  {'Name': 't Quentin', 'Entities': ['Quentin']},
#  {'Name': 'This mind', 'Entities': []},
#  {'Name': 'QT just', 'Entities': ['QT']},
#  {'Name': 'And', 'Entities': []},
#  {'Name': 'QT you', 'Entities': ['QT']},
#  {'Name': 'that Quentin', 'Entities': ['Quentin']},
#  {'Name': 'Yes Tarentino', 'Entities': ['Tarentino']},
#  {'Name': 'ALEC BALDWIN', 'Entities': ['ALEC BALDWIN']},
#  {'Name': 'DON CHEADLE', 'Entities': ['CHEADLE']},
#  {'Name': 'Jim Parsons', 'Entities': ['Jim Parsons']},
#  {'Name': 'don cheadle', 'Entities': ['don cheadle']},
#  {'Name': 'Cheadle just', 'Entities': ['Cheadle']},
#  {'Name': 'IamDonCheadle just', 'Entities': []},
#  {'Name': 'House Always', 'Entities': ['House']},
#  {'Name': 'as Quentin', 'Entities': ['Quentin']},
#  {'Name': 'jenniferlawrence', 'Entities': []},
#  {'Name': 's already', 'Entities': []},
#  {'Name': 'Hathaway deserve', 'Entities': ['Hathaway']},
#  {'Name': 'hair totally', 'Entities': []},
#  {'Name': 'Change and', 'Entities': []},
#  {'Name': 'he just', 'Entities': []},
#  {'Name': 'nor Sheldon', 'Entities': ['Sheldon']},
#  {'Name': 'last', 'Entities': []},
#  {'Name': 'Billy Murray', 'Entities': ['Billy Murray']},
#  {'Name': 'Sylvester Stallone', 'Entities': ['Sylvester Stallone']},
#  {'Name': 'but Amour', 'Entities': []},
#  {'Name': 'Machine have', 'Entities': []},
#  {'Name': 'GoldenGlobes Amour', 'Entities': ['GoldenGlobes Amour']},
#  {'Name': 'fav film', 'Entities': []},
#  {'Name': 'taratino', 'Entities': ['taratino']},
#  {'Name': 'speech impediments', 'Entities': []},
#  {'Name': 'LOTR', 'Entities': ['LOTR']},
#  {'Name': 'two', 'Entities': ['two']},
#  {'Name': 'that Tarantino', 'Entities': ['Tarantino']},
#  {'Name': 'from Austria', 'Entities': ['Austria']},
#  {'Name': 'guys who', 'Entities': []},
#  {'Name': 's dad', 'Entities': []},
#  {'Name': 'Connie Britton', 'Entities': ['Connie Britton']},
#  {'Name': 'Hale_Razor\nDjango', 'Entities': ['Django']},
#  {'Name': 'Clair Danes', 'Entities': ['Clair Danes']},
#  {'Name': 'Angela Chase', 'Entities': ['Angela Chase']},
#  {'Name': 'Homeland has', 'Entities': ['Homeland']},
#  {'Name': 'Downton Abbey', 'Entities': ['Downton Abbey']},
#  {'Name': 'train awards', 'Entities': []},
#  {'Name': 'Andy Dwyer', 'Entities': ['Andy Dwyer']},
#  {'Name': 'Danes aso', 'Entities': ['Danes']},
#  {'Name': 'is dominating', 'Entities': []},
#  {'Name': 'son', 'Entities': []},
#  {'Name': 'Crazy', 'Entities': []},
#  {'Name': 'hope Hugh', 'Entities': ['Hugh']},
#  {'Name': 'rackin the', 'Entities': []},
#  {'Name': 'Wait who', 'Entities': []},
#  {'Name': 'Michael Heneke', 'Entities': ['Michael Heneke']},
#  {'Name': 'Jennifer have', 'Entities': ['Jennifer']},
#  {'Name': 'NICOLE Kidman', 'Entities': ['NICOLE Kidman']},
#  {'Name': 'Another big', 'Entities': []},
#  {'Name': 'homeland has', 'Entities': []},
#  {'Name': 'Hathaway immediately', 'Entities': ['Hathaway']},
#  {'Name': 'Ralph', 'Entities': ['Ralph']},
#  {'Name': 'Disney', 'Entities': ['Disney']},
#  {'Name': 'awards homeland', 'Entities': []},
#  {'Name': 'GOD YOU', 'Entities': []},
#  {'Name': 'reason brave', 'Entities': []},
#  {'Name': 'YESSSSS DISNEY', 'Entities': ['YESSSSS DISNEY']},
#  {'Name': 'YAYAY BRAVE', 'Entities': []},
#  {'Name': 'Happy it', 'Entities': []},
#  {'Name': 'YAYYY BRAVE', 'Entities': []},
#  {'Name': 'Animated Series', 'Entities': []},
#  {'Name': 'it Ralph', 'Entities': ['Ralph']},
#  {'Name': 'glad Brave', 'Entities': []},
#  {'Name': 'Wooo Brave', 'Entities': []},
#  {'Name': 'It Ralph', 'Entities': ['Ralph']},
#  {'Name': 'OhNoSheTwitnt', 'Entities': []},
#  {'Name': 'PixarBrave', 'Entities': []},
#  {'Name': 'No', 'Entities': []},
#  {'Name': 'tweeting who', 'Entities': []},
#  {'Name': 'have been', 'Entities': []},
#  {'Name': 'archery lady', 'Entities': ['archery']},
#  {'Name': 'awww Brave', 'Entities': ['awww Brave']},
#  {'Name': 'and Carrie', 'Entities': ['Carrie']},
#  {'Name': 'brave just', 'Entities': []},
#  {'Name': 'and biggest', 'Entities': []},
#  {'Name': 'aziz', 'Entities': ['aziz']},
#  {'Name': 'head lady', 'Entities': []},
#  {'Name': 'Zooey Deschanel', 'Entities': ['Zooey Deschanel']},
#  {'Name': 'PIXAR', 'Entities': ['PIXAR']},
#  {'Name': 'my queen', 'Entities': []},
#  {'Name': 'WISH ZOOEY', 'Entities': []},
#  {'Name': 'hosts actually', 'Entities': []},
#  {'Name': 'AzizAnsari', 'Entities': ['AzizAnsari']},
#  {'Name': 'Poelher shouldve', 'Entities': ['Poelher']},
#  {'Name': 'If Zooey', 'Entities': ['Zooey']},
#  {'Name': 'Jonah Hill', 'Entities': ['Jonah Hill']},
#  {'Name': 'but Brave', 'Entities': []},
#  {'Name': 'the Girls', 'Entities': []},
#  {'Name': 'she definitely', 'Entities': []},
#  {'Name': 'Tarentino', 'Entities': ['Tarentino']},
#  {'Name': 'Lena just', 'Entities': ['Lena']},
#  {'Name': '30 Rock', 'Entities': ['30']},
#  {'Name': 'about this', 'Entities': []},
#  {'Name': 'lena dunham', 'Entities': ['lena dunham']},
#  {'Name': 'I never', 'Entities': []},
#  {'Name': 'audience and', 'Entities': []},
#  {'Name': 'Marina Sirtis', 'Entities': ['Marina Sirtis']},
#  {'Name': 'girl Lena', 'Entities': ['Lena']},
#  {'Name': 's Brave', 'Entities': []},
#  {'Name': 'Clooney bit', 'Entities': ['Clooney']},
#  {'Name': 'Matt Ryan', 'Entities': ['Matt Ryan']},
#  {'Name': 'Tarantino both', 'Entities': ['Tarantino']},
#  {'Name': 'the City', 'Entities': []},
#  {'Name': 'that', 'Entities': []},
#  {'Name': 'and Brave', 'Entities': []},
#  {'Name': '3IyTTqP4 Lawrence', 'Entities': ['3IyTTqP4']},
#  {'Name': 'that she', 'Entities': []},
#  {'Name': 's shoes', 'Entities': []},
#  {'Name': 'for has', 'Entities': []},
#  {'Name': 'lenadunham be', 'Entities': []},
#  {'Name': 'hear who', 'Entities': []},
#  {'Name': 'girl Julia', 'Entities': ['Julia']},
#  {'Name': 'patient that', 'Entities': []},
#  {'Name': 'that Hannah', 'Entities': ['Hannah']},
#  {'Name': 'fat trick', 'Entities': []},
#  {'Name': 'Texas chainsaw', 'Entities': ['Texas']},
#  {'Name': 'Golden Globes', 'Entities': ['Golden Globes']},
#  {'Name': 'The actress', 'Entities': []},
#  {'Name': 'Amy totally', 'Entities': ['Amy']},
#  {'Name': 'GIRLS that', 'Entities': []},
#  {'Name': 'Leon Durham', 'Entities': ['Leon Durham']},
#  {'Name': 'of privilege', 'Entities': []},
#  {'Name': 'Glenn Close', 'Entities': ['Glenn Close']},
#  {'Name': 'Glen Close', 'Entities': ['Glen Close']},
#  {'Name': 'AmyPoehler always', 'Entities': ['AmyPoehler']},
#  {'Name': 'tina fey', 'Entities': ['tina fey']},
#  {'Name': 'any Jews', 'Entities': ['Jews']},
#  {'Name': 'joke definitely', 'Entities': []},
#  {'Name': 'Foster has', 'Entities': ['Foster']},
#  {'Name': 'GoldenGlobes Brave', 'Entities': []},
#  {'Name': 'the Lambs', 'Entities': []},
#  {'Name': 'in who', 'Entities': []},
#  {'Name': 'mom Adele', 'Entities': ['Adele']},
#  {'Name': 'and Anne', 'Entities': ['Anne']},
#  {'Name': 'was that', 'Entities': []},
#  {'Name': 'the lambs', 'Entities': []},
#  {'Name': 'd', 'Entities': []},
#  {'Name': 'dinamanzo she', 'Entities': []},
#  {'Name': 'Mel Gibson', 'Entities': ['Mel Gibson']},
#  {'Name': 'Has Django', 'Entities': ['Django']},
#  {'Name': 'DonCheadle', 'Entities': []},
#  {'Name': 'when I', 'Entities': []},
#  {'Name': 'Jodi Foster', 'Entities': ['Jodi Foster']},
#  {'Name': 'like everything', 'Entities': []},
#  {'Name': 'ralph shoulda', 'Entities': ['ralph']},
#  {'Name': 's leg', 'Entities': []},
#  {'Name': 'Berry always', 'Entities': ['Berry']},
#  {'Name': 'Jodie', 'Entities': ['Jodie']},
#  {'Name': 'BEN AFLECK', 'Entities': ['BEN AFLECK']},
#  {'Name': 'Oscar and', 'Entities': ['Oscar']},
#  {'Name': 'Gigli just', 'Entities': ['Gigli']},
#  {'Name': 'when Affleck', 'Entities': ['Affleck']},
#  {'Name': 'but just', 'Entities': []},
#  {'Name': 'BenAffleck just', 'Entities': ['BenAffleck']},
#  {'Name': 'And Afleck', 'Entities': ['Afleck']},
#  {'Name': 'Afleck finally', 'Entities': ['Afleck']},
#  {'Name': 'Oscar snubbed', 'Entities': ['Oscar']},
#  {'Name': 'jaw line', 'Entities': []},
#  {'Name': 'Oscars', 'Entities': ['Oscars']},
#  {'Name': 'and Superman', 'Entities': ['Superman']},
#  {'Name': 'BenAfleck', 'Entities': ['BenAfleck']},
#  {'Name': 's still', 'Entities': []},
#  {'Name': 'Ben Afleck', 'Entities': ['Ben Afleck']},
#  {'Name': 'he had', 'Entities': []},
#  {'Name': 'director Affleck', 'Entities': ['Affleck']},
#  {'Name': 'Ben just', 'Entities': ['Ben']},
#  {'Name': 'Gardner definitely', 'Entities': ['Gardner']},
#  {'Name': 'happy Ben', 'Entities': ['Ben']},
#  {'Name': 'Bannion', 'Entities': []},
#  {'Name': 'that Affleck', 'Entities': ['Affleck']},
#  {'Name': 'the Mimi', 'Entities': ['Mimi']},
#  {'Name': 'on earth', 'Entities': []},
#  {'Name': 'Hathawy', 'Entities': []},
#  {'Name': 'has not', 'Entities': []},
#  {'Name': 'wish Episodes', 'Entities': []},
#  {'Name': 'You have', 'Entities': []},
#  {'Name': 'Smash had', 'Entities': ['Smash']},
#  {'Name': 'TV show', 'Entities': []},
#  {'Name': 'motion picture', 'Entities': []},
#  {'Name': 'girlsHBO just', 'Entities': []},
#  {'Name': 'that has', 'Entities': []},
#  {'Name': 'OMH GIRLS', 'Entities': []},
#  {'Name': 'YES GIRLS', 'Entities': []},
#  {'Name': 'GIRLS\nGIRLS', 'Entities': []},
#  {'Name': 'affleck', 'Entities': ['affleck']},
#  {'Name': 'favourite show', 'Entities': []},
#  {'Name': 'when it', 'Entities': []},
#  {'Name': 'GIRLS JUST', 'Entities': []},
#  {'Name': 'Troupe never', 'Entities': ['Troupe']},
#  {'Name': 'show has', 'Entities': []},
#  {'Name': 'if Bradley', 'Entities': ['Bradley']},
#  {'Name': 'dress who', 'Entities': []},
#  {'Name': 'all these', 'Entities': []},
#  {'Name': 'You just', 'Entities': []},
#  {'Name': 'GirlsHBO', 'Entities': []},
#  {'Name': 'AND SHE', 'Entities': []},
#  {'Name': 'Man Tate', 'Entities': []},
#  {'Name': 'OMG GIRLS', 'Entities': []},
#  {'Name': 'ben afleck', 'Entities': ['ben afleck']},
#  {'Name': 'award they', 'Entities': []},
#  {'Name': 'like I', 'Entities': []},
#  {'Name': 'adele even', 'Entities': ['adele']},
#  {'Name': 'are mostly', 'Entities': []},
#  {'Name': 'this girl', 'Entities': []},
#  {'Name': 'Yet he', 'Entities': []},
#  {'Name': 'Affleck just', 'Entities': ['Affleck']},
#  {'Name': 'has DJANGO', 'Entities': ['DJANGO']},
#  {'Name': 'unemployed mooches', 'Entities': []},
#  {'Name': 'ANA NG', 'Entities': ['ANA NG']},
#  {'Name': 'glad Affleck', 'Entities': ['Affleck']},
#  {'Name': 'LenaDunham has', 'Entities': ['LenaDunham']},
#  {'Name': 'girl who', 'Entities': []},
#  {'Name': 'lack of', 'Entities': []},
#  {'Name': 'Yay girl', 'Entities': []},
#  {'Name': 'min B4', 'Entities': []},
#  {'Name': 'STOP GIRLS', 'Entities': []},
#  {'Name': 'Ben Afflect', 'Entities': ['Ben Afflect']},
#  {'Name': 'WOLVERINE', 'Entities': ['WOLVERINE']},
#  {'Name': 'Murray shoulda', 'Entities': ['Murray']},
#  {'Name': 'Hey', 'Entities': []},
#  {'Name': 'finally we', 'Entities': []},
#  {'Name': 'because Hugh', 'Entities': ['Hugh']},
#  {'Name': 'Ewan had', 'Entities': ['Ewan']},
#  {'Name': 'Logan just', 'Entities': ['Logan']},
#  {'Name': 'that guy', 'Entities': []},
#  {'Name': 'shit Wolverine', 'Entities': ['Wolverine']},
#  {'Name': 'MAN WHO', 'Entities': []},
#  {'Name': 'Bill Murry', 'Entities': ['Bill Murry']},
#  {'Name': 'Aussie superstar', 'Entities': ['Aussie']},
#  {'Name': 'Jennifer Garner', 'Entities': ['Jennifer Garner']},
#  {'Name': 'has ever', 'Entities': []},
#  {'Name': 'jack off', 'Entities': ['jack']},
#  {'Name': 'it has', 'Entities': []},
#  {'Name': 'RealHughJackman Wolverine', 'Entities': ['Wolverine']},
#  {'Name': 'Head actor', 'Entities': []},
#  {'Name': 'many awards', 'Entities': []},
#  {'Name': 'other news', 'Entities': []},
#  {'Name': 'BRADLEY COOPER', 'Entities': ['BRADLEY COOPER']},
#  {'Name': 'jennifer garner', 'Entities': ['jennifer garner']},
#  {'Name': 'Huge Jackman', 'Entities': []},
#  {'Name': 'but he', 'Entities': []},
#  {'Name': 'ep and', 'Entities': []},
#  {'Name': 'Hathaway have', 'Entities': ['Hathaway']},
#  {'Name': 'see homeland', 'Entities': []},
#  {'Name': 'associated festivities', 'Entities': []},
#  {'Name': 'most series', 'Entities': []},
#  {'Name': 'the most', 'Entities': []},
#  {'Name': 'Jackman both', 'Entities': ['Jackman']},
#  {'Name': 'Lewis was', 'Entities': []},
#  {'Name': 'someone who', 'Entities': []},
#  {'Name': 'when Wolverine', 'Entities': ['Wolverine']},
#  {'Name': 'betcha someone', 'Entities': []},
#  {'Name': 'Cooper still', 'Entities': ['Cooper']},
#  {'Name': 'If Chastain', 'Entities': ['Chastain']},
#  {'Name': 'that girls', 'Entities': []},
#  {'Name': 'hope Lincoln', 'Entities': ['Lincoln']},
#  {'Name': 'that Squirrels', 'Entities': ['Squirrels']},
#  {'Name': 'realhughjackman', 'Entities': ['realhughjackman']},
#  {'Name': 'Les Miserable', 'Entities': []},
#  {'Name': 'Les miserablé', 'Entities': []},
#  {'Name': 'LesMisérables', 'Entities': ['LesMisérables']},
#  {'Name': 'Girls which', 'Entities': []},
#  {'Name': 'has just', 'Entities': []},
#  {'Name': 'MUSICAL THAT', 'Entities': []},
#  {'Name': 'yet it', 'Entities': []},
#  {'Name': 'Playbook shouldve', 'Entities': ['Playbook']},
#  {'Name': 'LesMisarables', 'Entities': ['LesMisarables']},
#  {'Name': 'stupid musical', 'Entities': []},
#  {'Name': 'Miserables has', 'Entities': ['Miserables']},
#  {'Name': 'Les Misèrables', 'Entities': ['Les Misèrables']},
#  {'Name': 'by Academy', 'Entities': ['Academy']},
#  {'Name': 'TheMiserable just', 'Entities': ['TheMiserable']},
#  {'Name': 'Les mis', 'Entities': []},
#  {'Name': 'Simpsons never', 'Entities': ['Simpsons']},
#  {'Name': 'les misérables', 'Entities': ['les misérables']},
#  {'Name': 'LesMiserables has', 'Entities': ['LesMiserables']},
#  {'Name': 'Comedy', 'Entities': []},
#  {'Name': 'It', 'Entities': []},
#  {'Name': 'Hot Topic', 'Entities': []},
#  {'Name': 'Mes has', 'Entities': ['Mes']},
#  {'Name': 'second film', 'Entities': ['second']},
#  {'Name': 'party Adele', 'Entities': ['Adele']},
#  {'Name': 'The musical', 'Entities': []},
#  {'Name': 'Chicago', 'Entities': ['Chicago']},
#  {'Name': 'hope bradley', 'Entities': ['bradley']},
#  {'Name': 'Grumpy Cat', 'Entities': []},
#  {'Name': 'and Mystique', 'Entities': ['Mystique']},
#  {'Name': 'Fox', 'Entities': ['Fox']},
#  {'Name': 'They have', 'Entities': []},
#  {'Name': 'Miserables both', 'Entities': ['Miserables']},
#  ...]

# %% [markdown]
# **CLUSTERING**
#
# Many names may be associated with a given entity
# - Identify names "similar" to the entity (ex: Anne Hathaway - anne hathaway, @annehathaway, etx )
# - Note that not every string may be mapped to an entity
#
# Quantifing "similarity" between strings i.e. string distance?
# - token overlap -> # times each word in string appears in each defined entity, return highest entity
# - loads of string metrics (https://en.wikipedia.org/wiki/String_metric) -> levenshtein, hamming, jaccard, etx (https://www.nltk.org/api/nltk.metrics.html#module-nltk.metrics.distance)
# - considerations for string metrics: some metrics require comparison of strings of identical length (ex: Hamming dist.)

# %% [markdown]
# Define Entity List to check against:
# - for testing purposes, eventually will need to extract these too

# %%
ENTITIES = [
    'Ben Affleck', 
    'Anne Hathaway', 
    'Julianne Moore', 
    'Adele', 
    'Jessica Chastain', 
    'Daniel Day-Lewis', 
    'Denzel Washington', 
    'Jonah Hill', 
    'Brad Pitt', 
    'Amy Poehler'
]

# %% [markdown]
# Simple Token Overlap
# - https://stackoverflow.com/questions/10136077/python-natural-language-processing-for-named-entities

# %%
def token_overlap(query_string, classes):
    """
    Computes the most "likely" class for the given query string.

    First normalises the query to lower case, then computes the number of
    overlapping tokens for each of the possible classes.

    The class(es) with the highest overlap are returned as a list.

    """
    query_tokens = query_string.lower().split() # lowercase query
    class_tokens = [[x.lower() for x in c.split()] for c in classes] # lowercase each class in CLASSES
    # print(f"tokens:{class_tokens}")


    overlap = [0] * len(classes) # num times each word in query string appears for each defined CLASS 
    # check overlap on word/token level, not char
    for token in query_tokens:
        for index in range(len(classes)): 
            if token in class_tokens[index]:
                overlap[index] += 1

    # print(overlap)

    sorted_overlap = [(count, index) for index, count in enumerate(overlap)]
    sorted_overlap.sort()
    sorted_overlap.reverse()

    best_count = sorted_overlap[0][0]

    best_classes = []
    for count, index in sorted_overlap:
        if count == best_count:
            best_classes.append(classes[index]) # include count to get (class name, overlap count)
        else:
            break

    return best_classes


print(token_overlap("and affleck with adele", classes=ENTITIES))
# Out:
# ['Adele', 'Ben Affleck']

# %%
from difflib import SequenceMatcher
s_1 = 'jiminkang'
s_2 = 'gnaknimij'
print(SequenceMatcher(a=s_1,b=s_2).ratio())
# Out:
# 0.3333333333333333

# %% [markdown]
# Given some list of entities, map names in output to each entity
#
# Aggregate the counts for each name into count for that entity
#
# "Winner" is entity with highest count

# %%
import random

# data structure -> entity : [different names]
entity_names = {}
entity_names = dict.fromkeys(ENTITIES, [])  

# data structure -> entity : count
entity_count = {}
entity_count = dict.fromkeys(ENTITIES, 0)  

winners = sorted(output["Winner"], key=lambda x: x["Number of Tweets"], reverse=True)

# traverse names in winners
for i in range(len(winners)):
    winner_name = winners[i]["Name"]
    # identify entities "closest" to winner_name
    candidate_entities = token_overlap(winner_name, classes=ENTITIES) # replace None w/ "ground truth" entity list
    identified_entity = candidate_entities[0] if len(candidate_entities) == 0 else random.choice(candidate_entities) # randomize out of highest similarity entities if case of tie
    
    # map name to entity, update entity count
    entity_names[identified_entity].append(winner_name)
    entity_count[identified_entity] += 1

    

# winner = entity w/ highest count
dict(sorted(entity_count.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'Adele': 170,
#  'Anne Hathaway': 128,
#  'Ben Affleck': 118,
#  'Jessica Chastain': 117,
#  'Amy Poehler': 113,
#  'Daniel Day-Lewis': 108,
#  'Jonah Hill': 107,
#  'Brad Pitt': 104,
#  'Denzel Washington': 99,
#  'Julianne Moore': 97}
